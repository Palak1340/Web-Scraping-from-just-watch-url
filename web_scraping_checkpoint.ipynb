# %% [markdown]
# <a href="https://colab.research.google.com/github/Palak1340/Web-Scraping-from-just-watch-url/blob/main/web_scraping_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # !DISCLAMER!

# %% [markdown]
# # Do not run all the code in one go run wise one by one take a rest of 30 second between one run  if you run all the code in one go not abe to fetch the data or not able to scrap the data so please kindly requested to not run alll the code in one go all the code are properly working . i alwready run the code and showcase the data

# %% [markdown]
# # Task 1:- Web Scrapping

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %% [markdown]
# # Scrapping Movies Data

# %%
# Specifying the URL from which movies related data will be fetched
url='https://www.justwatch.com/in/movies?release_year_from=2000'

# Sending an HTTP GET request to the URL
page=requests.get(url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
# ...

# %% [markdown]
# # Scrapping Movie Title

# %%
# Movie title
movie_title_list = []  # List to store all movie titles

# Extracting all movie titles from <a> tag and storing them in movie_titles
movie_titles = soup.find_all('a', class_="title-list-grid__item--link", attrs={'href': True})

# Extracting each movie title from movie_titles and storing in movie_title_list
for movie_title in movie_titles:
    # Extract the 'href' attribute value, which contains the movie title
    data_id_value = movie_title['href']

    # Removing the '/in/movie/' prefix to get the clean movie title
    data_id_value = data_id_value.replace("/in/movie/", "").upper()

    # Appending the cleaned movie title to the list
    movie_title_list.append(data_id_value)

# Print the list to check the extracted movie titles
print(movie_title_list)
# Out:
# ['DUNE-2021', 'OPPENHEIMER', 'ANIMAL-2022', 'SALAAR', 'DUNKI', '12TH-FAIL', 'POOR-THINGS', 'THE-KERALA-STORY', 'HANU-MAN', 'ANYONE-BUT-YOU', 'SAM-BAHADUR', 'EAGLE-2024', 'ARTICLE-370', 'AYALAAN', 'CAPTAIN-MILLER', 'MERRY-CHRISTMAS-2024', 'UNTITLED-SHAHID-KAPOOR-KRITI-SANON-FILM', 'SSMB-28', 'FIGHTER-2022', 'ANATOMIE-DUNE-CHUTE', 'AQUAMAN-AND-THE-LOST-KINGDOM', 'ANWESHIPPIN-KANDETHUM', 'JAWAN', 'MANJUMMEL-BOYS', 'DUNE-PART-TWO', 'CODE-8', 'UNTITLED-CORD-JEFFERSON-FILM', 'SINGAPORE-SALOON', 'LAAPATAA-LADIES', '365-DAYS', 'DAMSEL-2023', 'CRAKK-JEETEGAA-TOH-JIYEGAA', 'THE-ZONE-OF-INTEREST', 'SOUND-OF-FREEDOM', 'BRAMAYUGAM', 'UPGRADED', 'PREMALU', 'THE-HOLDOVERS', 'THE-MARVELS', 'HARRY-POTTER-AND-THE-PHILOSOPHERS-STONE', 'KILLERS-OF-THE-FLOWER-MOON', 'THE-BEEKEEPER-2024', 'PAST-LIVES', 'MALAIKOTTAI-VAALIBAN', 'BARBIE-2023', 'NERU', 'BLUE-STAR', 'MIGRATION', 'CODE-8-PART-II', 'JUNIOR-2023', 'GODZILLA-MINUS-ONE', 'BLACKBERRY', 'VADAKKUPATTI-RAMASAMY', 'BHAKSHAK', 'NAADU', 'THE-WOLF-OF-WALL-
# ...

# %%
movie_title_list
# Out:
# ['DUNE-2021',
#  'OPPENHEIMER',
#  'ANIMAL-2022',
#  'SALAAR',
#  'DUNKI',
#  '12TH-FAIL',
#  'POOR-THINGS',
#  'THE-KERALA-STORY',
#  'HANU-MAN',
#  'ANYONE-BUT-YOU',
#  'SAM-BAHADUR',
#  'EAGLE-2024',
#  'ARTICLE-370',
#  'AYALAAN',
#  'CAPTAIN-MILLER',
#  'MERRY-CHRISTMAS-2024',
#  'UNTITLED-SHAHID-KAPOOR-KRITI-SANON-FILM',
#  'SSMB-28',
#  'FIGHTER-2022',
#  'ANATOMIE-DUNE-CHUTE',
#  'AQUAMAN-AND-THE-LOST-KINGDOM',
#  'ANWESHIPPIN-KANDETHUM',
#  'JAWAN',
#  'MANJUMMEL-BOYS',
#  'DUNE-PART-TWO',
#  'CODE-8',
#  'UNTITLED-CORD-JEFFERSON-FILM',
#  'SINGAPORE-SALOON',
#  'LAAPATAA-LADIES',
#  '365-DAYS',
#  'DAMSEL-2023',
#  'CRAKK-JEETEGAA-TOH-JIYEGAA',
#  'THE-ZONE-OF-INTEREST',
#  'SOUND-OF-FREEDOM',
#  'BRAMAYUGAM',
#  'UPGRADED',
#  'PREMALU',
#  'THE-HOLDOVERS',
#  'THE-MARVELS',
#  'HARRY-POTTER-AND-THE-PHILOSOPHERS-STONE',
#  'KILLERS-OF-THE-FLOWER-MOON',
#  'THE-BEEKEEPER-2024',
#  'PAST-LIVES',
#  'MALAIKOTTAI-VAALIBAN',
#  'BARBIE-2023',
#  'NERU',
#  'BLUE-STAR',
# ...

# %% [markdown]
# # Fetching Movie URL's

# %%
# Movie url

movie_url_list=[] # List to store all movie urls

# For every movie title present in movies_title_list , Finding their url
for movie in movie_title_list:

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie
    movie_url_list.append(absolute_url)

# %%
movie_url_list
# Out:
# ['https://www.justwatch.com/in/movie/DUNE-2021',
#  'https://www.justwatch.com/in/movie/OPPENHEIMER',
#  'https://www.justwatch.com/in/movie/ANIMAL-2022',
#  'https://www.justwatch.com/in/movie/SALAAR',
#  'https://www.justwatch.com/in/movie/DUNKI',
#  'https://www.justwatch.com/in/movie/12TH-FAIL',
#  'https://www.justwatch.com/in/movie/POOR-THINGS',
#  'https://www.justwatch.com/in/movie/THE-KERALA-STORY',
#  'https://www.justwatch.com/in/movie/HANU-MAN',
#  'https://www.justwatch.com/in/movie/ANYONE-BUT-YOU',
#  'https://www.justwatch.com/in/movie/SAM-BAHADUR',
#  'https://www.justwatch.com/in/movie/EAGLE-2024',
#  'https://www.justwatch.com/in/movie/ARTICLE-370',
#  'https://www.justwatch.com/in/movie/AYALAAN',
#  'https://www.justwatch.com/in/movie/CAPTAIN-MILLER',
#  'https://www.justwatch.com/in/movie/MERRY-CHRISTMAS-2024',
#  'https://www.justwatch.com/in/movie/UNTITLED-SHAHID-KAPOOR-KRITI-SANON-FILM',
#  'https://www.justwatch.com/in/movie/SSMB-28',
# ...

# %% [markdown]
# # Scrapping release Year

# %%
# List to store all movie release years
movie_release_year_list = []

# For every movie title present in movies_title_list, find their release year
for i in range(0,10):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list.append('None')

# %%
movie_release_year_list
# Out:
# [' 2021 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ']

# %%
# List to store all movie release years
movie_release_year_list2 = []

# For every movie title present in movies_title_list, find their release year
for i in range(10,20):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list2.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list2.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list2.append('None')

# %%
movie_release_year_list2
# Out:
# [' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2023 ']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all movie release years
movie_release_year_list3 = []

# For every movie title present in movies_title_list, find their release year
for i in range(20,30):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list3.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list3.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list3.append('None')

# %%
movie_release_year_list3
# Out:
# [' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2019 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2020 ']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all movie release years
movie_release_year_list4 = []

# For every movie title present in movies_title_list, find their release year
for i in range(30,40):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list4.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list4.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list4.append('None')

# %%
movie_release_year_list4
# Out:
# [' 2024 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2001 ']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all movie release years
movie_release_year_list5 = []

# For every movie title present in movies_title_list, find their release year
for i in range(40,50):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list5.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list5.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list5.append('None')

# %%
movie_release_year_list5
# Out:
# [' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all movie release years
movie_release_year_list6 = []

# For every movie title present in movies_title_list, find their release year
for i in range(50,60):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list6.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list6.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list6.append('None')

# %%
movie_release_year_list6
# Out:
# [' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2013 ',
#  ' 2023 ',
#  ' 2016 ',
#  ' 2023 ',
#  ' 2018 ']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all movie release years
movie_release_year_list7 = []

# For every movie title present in movies_title_list, find their release year
for i in range(60,70):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list7.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list7.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list7.append('None')

# %%
movie_release_year_list7
# Out:
# [' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2014 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2019 ',
#  ' 2024 ']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all movie release years
movie_release_year_list8 = []

# For every movie title present in movies_title_list, find their release year
for i in range(70,80):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list8.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list8.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list8.append('None')

# %%
movie_release_year_list8
# Out:
# [' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2008 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2000 ']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all movie release years
movie_release_year_list9 = []

# For every movie title present in movies_title_list, find their release year
for i in range(80,90):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list9.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list9.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list9.append('None')

# %%
movie_release_year_list9
# Out:
# [' 2019 ',
#  ' 2022 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2011 ',
#  ' 2023 ',
#  ' 2018 ',
#  ' 2024 ',
#  ' 2016 ']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all movie release years
movie_release_year_list10 = []

# For every movie title present in movies_title_list, find their release year
for i in range(90,100):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]

    # Send an HTTP GET request to the URL
    response_ry = requests.get(absolute_url)

    # Check if the request was successful
    if response_ry.status_code == 200:
        # Parse HTML content with BeautifulSoup
        soup_ry = BeautifulSoup(response_ry.text, 'html.parser')

        # Find the span containing the release year
        release_year_span = soup_ry.find('span', class_='text-muted')

        # Extract the release year
        if release_year_span:
            movie_release_year = release_year_span.text.replace("(", "").replace(")", "")
            movie_release_year_list10.append(movie_release_year)
        else:
            # If release year span is not found, append None to the list
            movie_release_year_list10.append(None)
    else:
        # If the request was not successful, append None to the list
        movie_release_year_list10.append('None')

# %%
movie_release_year_list10
# Out:
# [' 2023 ',
#  ' 2023 ',
#  ' 2017 ',
#  ' 2021 ',
#  ' 2020 ',
#  ' 2021 ',
#  ' 2021 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ']

# %%
all_release_years = []

# Loop through all movie release year lists
for year_list in [movie_release_year_list,movie_release_year_list2,movie_release_year_list3,movie_release_year_list4,movie_release_year_list5,movie_release_year_list6,movie_release_year_list7,movie_release_year_list8,movie_release_year_list9,movie_release_year_list10]:
  all_release_years.extend(year_list)  # Add each element of the list

print(all_release_years)
# Out:
# [' 2021 ', ' 2023 ', ' 2023 ', ' 2023 ', ' 2023 ', ' 2023 ', ' 2023 ', ' 2023 ', ' 2024 ', ' 2023 ', ' 2023 ', ' 2024 ', ' 2024 ', ' 2024 ', ' 2024 ', ' 2024 ', ' 2024 ', ' 2024 ', ' 2024 ', ' 2023 ', ' 2023 ', ' 2024 ', ' 2023 ', ' 2024 ', ' 2024 ', ' 2019 ', ' 2023 ', ' 2024 ', ' 2024 ', ' 2020 ', ' 2024 ', ' 2024 ', ' 2023 ', ' 2023 ', ' 2024 ', ' 2024 ', ' 2024 ', ' 2023 ', ' 2023 ', ' 2001 ', ' 2023 ', ' 2024 ', ' 2023 ', ' 2024 ', ' 2023 ', ' 2023 ', ' 2024 ', ' 2023 ', ' 2024 ', ' 2023 ', ' 2023 ', ' 2023 ', ' 2024 ', ' 2024 ', ' 2023 ', ' 2013 ', ' 2023 ', ' 2016 ', ' 2023 ', ' 2018 ', ' 2023 ', ' 2023 ', ' 2023 ', ' 2023 ', ' 2014 ', ' 2023 ', ' 2023 ', ' 2024 ', ' 2019 ', ' 2024 ', ' 2023 ', ' 2023 ', ' 2023 ', ' 2024 ', ' 2023 ', ' 2008 ', ' 2023 ', ' 2024 ', ' 2023 ', ' 2000 ', ' 2019 ', ' 2022 ', ' 2023 ', ' 2024 ', ' 2023 ', ' 2011 ', ' 2023 ', ' 2018 ', ' 2024 ', ' 2016 ', ' 2023 ', ' 2023 ', ' 2017 ', ' 2021 ', ' 2020 ', ' 2021 ', ' 2021 ', ' 2024 ', ' 2023 ', ' 2023 
# ...

# %%
all_release_years
# Out:
# [' 2021 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2019 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2020 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2001 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2013 ',
#  ' 2023 ',
#  ' 2016 ',
#  ' 2023 ',
#  ' 2018 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2014 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2019 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2023 ',
#  ' 2024 ',
#  ' 2023 ',
#  ' 2008 ',
# ...

# %% [markdown]
# # Scrapping release Year

# %%
# Write Your Code here

# Movie genre

movie_genre_list1 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(0,10):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list1.append(div_element.text.strip())
        else:
            movie_genre_list1.append("Genre Not Listed")
    else:
         movie_genre_list1.append("Genre Not Listed")

# %%
movie_genre_list1
# Out:
# ['Science-Fiction, Action & Adventure, Drama',
#  'Drama, History',
#  'Crime, Drama, Action & Adventure, Mystery & Thriller',
#  'Action & Adventure, Crime, Drama, Mystery & Thriller',
#  'Comedy, Drama',
#  'Drama, History',
#  'Comedy, Science-Fiction, Romance, Drama',
#  'Drama',
#  'Science-Fiction, Fantasy, Action & Adventure, Comedy',
#  'Comedy, Romance']

# %%
# Write Your Code here

# Movie genre

movie_genre_list2 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(10,20):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list2.append(div_element.text.strip())
        else:
            movie_genre_list2.append("Genre Not Listed")
    else:
         movie_genre_list2.append("Genre Not Listed")

# %%
movie_genre_list2
# Out:
# ['Drama, War & Military',
#  'Action & Adventure, Mystery & Thriller',
#  'Mystery & Thriller, Action & Adventure, Drama',
#  'Science-Fiction, Action & Adventure',
#  'Action & Adventure, Drama, Mystery & Thriller, War & Military',
#  'Mystery & Thriller, Drama',
#  'Science-Fiction, Comedy, Drama, Romance',
#  'Drama, Kids & Family, Action & Adventure',
#  'Mystery & Thriller, Action & Adventure, War & Military',
#  'Mystery & Thriller, Crime, Drama']

# %%
# Write Your Code here

# Movie genre

movie_genre_list3 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(20,30):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list3.append(div_element.text.strip())
        else:
            movie_genre_list3.append("Genre Not Listed")
    else:
         movie_genre_list3.append("Genre Not Listed")

# %%
movie_genre_list3
# Out:
# ['Fantasy, Action & Adventure, Science-Fiction',
#  'Crime, Drama, Mystery & Thriller',
#  'Action & Adventure, Mystery & Thriller, Drama',
#  'Mystery & Thriller, Drama',
#  'Science-Fiction, Action & Adventure, Drama',
#  'Crime, Science-Fiction, Action & Adventure, Mystery & Thriller, Drama',
#  'Drama, Comedy',
#  'Kids & Family, Comedy, Drama',
#  'Drama, Comedy',
#  'Drama, Romance, Made in Europe']

# %%
# Write Your Code here

# Movie genre

movie_genre_list4 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(30,40):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list4.append(div_element.text.strip())
        else:
            movie_genre_list4.append("Genre Not Listed")
    else:
         movie_genre_list4.append("Genre Not Listed")

# %%
movie_genre_list4
# Out:
# ['Fantasy, Action & Adventure',
#  'Action & Adventure, Mystery & Thriller, Sport',
#  'Drama, History, War & Military',
#  'Action & Adventure, Drama, Mystery & Thriller, Crime, History',
#  'Horror, Mystery & Thriller',
#  'Romance, Comedy',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Science-Fiction, Action & Adventure',
#  'Action & Adventure, Fantasy, Kids & Family']

# %%
# Write Your Code here

# Movie genre

movie_genre_list5 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(40,50):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list5.append(div_element.text.strip())
        else:
            movie_genre_list5.append("Genre Not Listed")
    else:
         movie_genre_list5.append("Genre Not Listed")

# %%
movie_genre_list5
# Out:
# ['Drama, Crime, History, Western, Romance',
#  'Mystery & Thriller, Drama, Action & Adventure',
#  'Drama, Romance',
#  'Drama, Fantasy, Action & Adventure, Western, Mystery & Thriller',
#  'Action & Adventure, Comedy, Fantasy',
#  'Mystery & Thriller, Drama',
#  'Sport, Comedy, Drama',
#  'Comedy, Kids & Family, Animation',
#  'Science-Fiction, Action & Adventure, Crime, Mystery & Thriller, Drama',
#  'Action & Adventure']

# %%
# Write Your Code here

# Movie genre

movie_genre_list6 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(50,60):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list6.append(div_element.text.strip())
        else:
            movie_genre_list6.append("Genre Not Listed")
    else:
         movie_genre_list6.append("Genre Not Listed")

# %%
movie_genre_list6
# Out:
# ['Science-Fiction, Horror, Action & Adventure, Drama',
#  'Comedy, Drama, History',
#  'Comedy, Drama, Fantasy, Science-Fiction',
#  'Crime, Drama',
#  'Drama',
#  'Drama, Comedy, Crime',
#  'Kids & Family, Romance, Drama',
#  'Drama, History, War & Military',
#  'Comedy, Drama, Romance',
#  'Mystery & Thriller, Drama, Action & Adventure, Crime']

# %%
# Write Your Code here

# Movie genre

movie_genre_list7 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(60,70):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list7.append(div_element.text.strip())
        else:
            movie_genre_list7.append("Genre Not Listed")
    else:
         movie_genre_list7.append("Genre Not Listed")

# %%
movie_genre_list7
# Out:
# ['Action & Adventure, Drama, History, War & Military',
#  'Romance, Comedy',
#  'Action & Adventure, Drama, Romance',
#  'Drama, Mystery & Thriller',
#  'Drama, Science-Fiction, Action & Adventure',
#  'Mystery & Thriller, Action & Adventure',
#  'Action & Adventure, Crime, Mystery & Thriller, Drama',
#  'Drama, Action & Adventure',
#  'Drama, History, War & Military, Action & Adventure',
#  'Genre Not Listed']

# %%
# Write Your Code here

# Movie genre

movie_genre_list8 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(70,80):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list8.append(div_element.text.strip())
        else:
            movie_genre_list8.append("Genre Not Listed")
    else:
         movie_genre_list8.append("Genre Not Listed")

# %%
movie_genre_list8
# Out:
# ['Action & Adventure, Crime, Drama, Mystery & Thriller, History',
#  'Mystery & Thriller, Action & Adventure, Crime',
#  'Drama, Romance, Comedy, Kids & Family',
#  'Drama, Science-Fiction, Action & Adventure',
#  'Mystery & Thriller, Drama',
#  'Action & Adventure, Animation, Kids & Family, Comedy, Fantasy',
#  'Action & Adventure, Mystery & Thriller',
#  'Mystery & Thriller, Crime, Drama',
#  'Comedy, Kids & Family, Fantasy',
#  'Genre Not Listed']

# %%
# Write Your Code here

# Movie genre

movie_genre_list9 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(80,90):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list9.append(div_element.text.strip())
        else:
            movie_genre_list9.append("Genre Not Listed")
    else:
         movie_genre_list9.append("Genre Not Listed")

# %%
movie_genre_list9
# Out:
# ['Drama, Action & Adventure, Comedy',
#  'Drama, Comedy',
#  'Drama, History, Mystery & Thriller',
#  'Drama',
#  'Drama, Action & Adventure, Mystery & Thriller',
#  'Drama, Romance',
#  'Action & Adventure, Science-Fiction, Mystery & Thriller',
#  'Fantasy, Horror, Mystery & Thriller, Drama, Made in Europe',
#  'Fantasy, Mystery & Thriller, Horror',
#  'Action & Adventure, Comedy']

# %%
# Write Your Code here

# Movie genre

movie_genre_list10 = []# List to store all movie genre

# For every movie title present in movies_title_list , Finding their genre
for i in range(90,100):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' +  movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_genre_list10.append(div_element.text.strip())
        else:
            movie_genre_list10.append("Genre Not Listed")
    else:
         movie_genre_list10.append("Genre Not Listed")

# %%
movie_genre_list10
# Out:
# ['Comedy, Romance, Drama, Kids & Family',
#  'Science-Fiction, Action & Adventure, Fantasy',
#  'Drama, Science-Fiction, Mystery & Thriller, Action & Adventure',
#  'Action & Adventure, Science-Fiction, Fantasy',
#  'Action & Adventure, Crime',
#  'Action & Adventure, Drama, Mystery & Thriller, Crime',
#  'Drama, Mystery & Thriller, Crime',
#  'Drama',
#  'Comedy, Drama, Kids & Family, Romance',
#  'Mystery & Thriller, Drama, Comedy']

# %%
all_movie_genre_list = []

# Loop through all movie release year lists
for genre_list in [movie_genre_list1,movie_genre_list2,movie_genre_list3,movie_genre_list4,movie_genre_list5,movie_genre_list6,movie_genre_list7,movie_genre_list8,movie_genre_list9,movie_genre_list10]:
  all_movie_genre_list.extend(genre_list)  # Add each element of the list

print(all_movie_genre_list)
# Out:
# ['Science-Fiction, Action & Adventure, Drama', 'Drama, History', 'Crime, Drama, Action & Adventure, Mystery & Thriller', 'Action & Adventure, Crime, Drama, Mystery & Thriller', 'Comedy, Drama', 'Drama, History', 'Comedy, Science-Fiction, Romance, Drama', 'Drama', 'Science-Fiction, Fantasy, Action & Adventure, Comedy', 'Comedy, Romance', 'Drama, War & Military', 'Action & Adventure, Mystery & Thriller', 'Mystery & Thriller, Action & Adventure, Drama', 'Science-Fiction, Action & Adventure', 'Action & Adventure, Drama, Mystery & Thriller, War & Military', 'Mystery & Thriller, Drama', 'Science-Fiction, Comedy, Drama, Romance', 'Drama, Kids & Family, Action & Adventure', 'Mystery & Thriller, Action & Adventure, War & Military', 'Mystery & Thriller, Crime, Drama', 'Fantasy, Action & Adventure, Science-Fiction', 'Crime, Drama, Mystery & Thriller', 'Action & Adventure, Mystery & Thriller, Drama', 'Mystery & Thriller, Drama', 'Science-Fiction, Action & Adventure, Drama', 'Crime, Science-Ficti
# ...

# %% [markdown]
# # Scrapping IMBD Rating

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(0,10):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list.append(span_last.text.strip())
                        else:
                            movie_imdb_list.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list.append("IMDb Rating Not Listed")

# %%
movie_imdb_list
# Out:
# ['8.0  (807k)',
#  '8.4  (676k)',
#  '6.3  (84k)',
#  '6.5  (61k)',
#  '6.7  (70k)',
#  '9.0  (104k)',
#  '8.1  (166k)',
#  '7.0  (69k)',
#  '8.4  (18k)',
#  '6.2  (49k)']

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list2 = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(10,20):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list2.append(span_last.text.strip())
                        else:
                            movie_imdb_list2.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list2.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list2.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list2.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list2.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list2.append("IMDb Rating Not Listed")

# %%
movie_imdb_list2
# Out:
# ['7.8  (14k)',
#  '6.8  (3k)',
#  '8.5  (9k)',
#  '6.0  (3k)',
#  '6.6  (5k)',
#  '7.3  (21k)',
#  '7.0  (42k)',
#  '5.4  (19k)',
#  '6.9  (37k)',
#  '7.8  (87k)']

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list3 = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(20,30):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list3.append(span_last.text.strip())
                        else:
                            movie_imdb_list3.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list3.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list3.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list3.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list3.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list3.append("IMDb Rating Not Listed")

# %%
movie_imdb_list3
# Out:
# ['5.6  (70k)',
#  '7.7  (3k)',
#  '7.0  (93k)',
#  '8.7  (4k)',
#  '8.9  (210k)',
#  '6.1  (49k)',
#  '7.6  (50k)',
#  '6.2',
#  '8.4  (1k)',
#  '3.3  (97k)']

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list4 = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(30,40):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list4.append(span_last.text.strip())
                        else:
                            movie_imdb_list4.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list4.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list4.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list4.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list4.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list4.append("IMDb Rating Not Listed")

# %%
movie_imdb_list4
# Out:
# ['6.2  (28k)',
#  '6.4  (4k)',
#  '7.5  (53k)',
#  '7.7  (110k)',
#  '8.4  (3k)',
#  '6.1  (15k)',
#  '8.3  (2k)',
#  '8.0  (119k)',
#  'IMDb Rating Not Listed',
#  'IMDb Rating Not Listed']

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list5 = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(40,50):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list5.append(span_last.text.strip())
                        else:
                            movie_imdb_list5.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list5.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list5.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list5.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list5.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list5.append("IMDb Rating Not Listed")

# %%
movie_imdb_list5
# Out:
# ['7.6  (221k)',
#  '6.4  (66k)',
#  '7.9  (102k)',
#  '6.4  (3k)',
#  '6.9  (512k)',
#  '7.6  (5k)',
#  '7.1',
#  '6.7  (19k)',
#  '5.7  (7k)',
#  '7.7']

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list6 = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(50,60):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list6.append(span_last.text.strip())
                        else:
                            movie_imdb_list6.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list6.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list6.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list6.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list6.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list6.append("IMDb Rating Not Listed")

# %%
movie_imdb_list6
# Out:
# ['8.3  (45k)',
#  '7.4  (38k)',
#  '6.5',
#  '7.2  (4k)',
#  '7.1',
#  '8.2  (1m)',
#  '8.2  (14k)',
#  '8.1  (588k)',
#  '7.8',
#  'IMDb Rating Not Listed']

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list7 = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(60,70):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list7.append(span_last.text.strip())
                        else:
                            movie_imdb_list7.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list7.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list7.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list7.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list7.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list7.append("IMDb Rating Not Listed")

# %%
movie_imdb_list7
# Out:
# ['6.4  (124k)',
#  '6.8  (1k)',
#  '8.1  (2k)',
#  '7.0',
#  '8.7  (2m)',
#  '7.7  (238k)',
#  '7.2  (57k)',
#  '4.5',
#  'IMDb Rating Not Listed',
#  'IMDb Rating Not Listed']

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list8 = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(70,80) :
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list8.append(span_last.text.strip())
                        else:
                            movie_imdb_list8.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list8.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list8.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list8.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list8.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list8.append("IMDb Rating Not Listed")

# %%
movie_imdb_list8
# Out:
# ['6.1  (3k)',
#  '5.8  (116k)',
#  '6.7  (14k)',
#  '5.8  (20k)',
#  '7.9  (9k)',
#  '7.6  (515k)',
#  '5.8  (52k)',
#  '7.0',
#  '7.1  (113k)',
#  '8.2  (905k)']

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list9 = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(80,90):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list9.append(span_last.text.strip())
                        else:
                            movie_imdb_list9.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list9.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list9.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list9.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list9.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list9.append("IMDb Rating Not Listed")

# %%
movie_imdb_list9
# Out:
# ['7.6  (101k)',
#  '8.7  (39k)',
#  '7.8  (117k)',
#  '8.5  (1k)',
#  '5.2  (22k)',
#  '7.0  (165k)',
#  '6.0  (91k)',
#  '8.2  (58k)',
#  '6.0  (1k)',
#  '8.0  (1m)']

# %%
import requests
from bs4 import BeautifulSoup

# List to store all movie IMDb ratings
movie_imdb_list10 = []

# For every movie title present in movie_title_list, find their IMDb rating
for i in range(90,100):
    # Construct the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with the heading "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Find the next sibling div element with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside the div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                if inside_div:
                    inside_div_last = inside_div[-1]  # Get the last div element

                    if inside_div_last:
                        # Find all span elements inside the last div
                        span_all = inside_div_last.find_all('span')

                        if span_all:
                            span_last = span_all[-1]  # Get the last span element containing the rating
                            movie_imdb_list10.append(span_last.text.strip())
                        else:
                            movie_imdb_list10.append("IMDb Rating Not Listed")
                    else:
                        movie_imdb_list10.append("IMDb Rating Not Listed")
                else:
                    movie_imdb_list10.append("IMDb Rating Not Listed")
            else:
                movie_imdb_list10.append("IMDb Rating Not Listed")
        else:
            movie_imdb_list10.append("IMDb Rating Not Listed")
    else:
        movie_imdb_list10.append("IMDb Rating Not Listed")

# %%
movie_imdb_list10
# Out:
# ['8.1  (5k)',
#  '6.7  (204k)',
#  '8.0  (655k)',
#  '8.2  (869k)',
#  '7.8  (388k)',
#  '7.6  (86k)',
#  '5.2  (2k)',
#  '7.3  (3k)',
#  '6.5  (41k)',
#  '7.0  (189k)']

# %%
all_movie_imdb_list = []

# Loop through all movie release year lists
for imdb_list in [movie_imdb_list,movie_imdb_list2,movie_imdb_list3,movie_imdb_list4,movie_imdb_list5,movie_imdb_list6,movie_imdb_list7,movie_imdb_list8,movie_imdb_list9,movie_imdb_list10]:
  all_movie_imdb_list.extend(imdb_list)  # Add each element of the list

print(all_movie_imdb_list)
# Out:
# ['8.0  (807k)', '8.4  (676k)', '6.3  (84k)', '6.5  (61k)', '6.7  (70k)', '9.0  (104k)', '8.1  (166k)', '7.0  (69k)', '8.4  (18k)', '6.2  (49k)', '7.8  (14k)', '6.8  (3k)', '8.5  (9k)', '6.0  (3k)', '6.6  (5k)', '7.3  (21k)', '7.0  (42k)', '5.4  (19k)', '6.9  (37k)', '7.8  (87k)', '5.6  (70k)', '7.7  (3k)', '7.0  (93k)', '8.7  (4k)', '8.9  (210k)', '6.1  (49k)', '7.6  (50k)', '6.2', '8.4  (1k)', '3.3  (97k)', '6.2  (28k)', '6.4  (4k)', '7.5  (53k)', '7.7  (110k)', '8.4  (3k)', '6.1  (15k)', '8.3  (2k)', '8.0  (119k)', 'IMDb Rating Not Listed', 'IMDb Rating Not Listed', '7.6  (221k)', '6.4  (66k)', '7.9  (102k)', '6.4  (3k)', '6.9  (512k)', '7.6  (5k)', '7.1', '6.7  (19k)', '5.7  (7k)', '7.7', '8.3  (45k)', '7.4  (38k)', '6.5', '7.2  (4k)', '7.1', '8.2  (1m)', '8.2  (14k)', '8.1  (588k)', '7.8', 'IMDb Rating Not Listed', '6.4  (124k)', '6.8  (1k)', '8.1  (2k)', '7.0', '8.7  (2m)', '7.7  (238k)', '7.2  (57k)', '4.5', 'IMDb Rating Not Listed', 'IMDb Rating Not Listed', '6.1  (3k)', '5.8 
# ...

# %% [markdown]
# # Scrapping Runtime/Duration

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list1=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(0,10):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list1.append(div_element.text.strip())
        else:
            movie_runtime_list1.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list1.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list1
# Out:
# ['2h 35min',
#  '3h 0min',
#  '3h 21min',
#  '2h 55min',
#  '2h 40min',
#  '2h 27min',
#  '2h 22min',
#  '2h 18min',
#  '2h 39min',
#  '1h 43min']

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list2=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(10,20):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list2.append(div_element.text.strip())
        else:
            movie_runtime_list2.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list2.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list2
# Out:
# ['2h 30min',
#  '2h 39min',
#  '2h 38min',
#  '2h 35min',
#  '2h 37min',
#  '2h 23min',
#  '2h 21min',
#  '2h 39min',
#  '2h 47min',
#  '2h 32min']

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list3=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(20,30):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list3.append(div_element.text.strip())
        else:
            movie_runtime_list3.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list3.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list3
# Out:
# ['2h 4min',
#  '2h 22min',
#  '2h 49min',
#  '2h 15min',
#  '2h 47min',
#  '1h 39min',
#  '1h 57min',
#  '2h 17min',
#  '2h 2min',
#  '1h 54min']

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list4=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(30,40):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list4.append(div_element.text.strip())
        else:
            movie_runtime_list4.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list4.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list4
# Out:
# ['1h 50min',
#  '2h 34min',
#  '1h 46min',
#  '2h 11min',
#  '2h 19min',
#  '1h 45min',
#  '2h 36min',
#  '2h 13min',
#  '1h 45min',
#  '2h 32min']

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list5=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(40,50):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list5.append(div_element.text.strip())
        else:
            movie_runtime_list5.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list5.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list5
# Out:
# ['3h 26min',
#  '1h 45min',
#  '1h 46min',
#  '2h 34min',
#  '1h 54min',
#  '2h 30min',
#  '2h 46min',
#  '1h 23min',
#  '1h 41min',
#  '2h 2min']

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list6=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(50,60):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list6.append(div_element.text.strip())
        else:
            movie_runtime_list6.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list6.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list6
# Out:
# ['2h 5min',
#  '2h 0min',
#  '2h 24min',
#  '2h 14min',
#  '2h 8min',
#  '3h 0min',
#  '2h 35min',
#  '2h 19min',
#  '1h 30min',
#  '2h 36min']

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list7=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(60,70):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list7.append(div_element.text.strip())
        else:
            movie_runtime_list7.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list7.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list7
# Out:
# ['2h 38min',
#  '2h 35min',
#  '2h 28min',
#  '1h 52min',
#  '2h 49min',
#  '2h 44min',
#  '2h 43min',
#  '2h 30min',
#  '2h 18min',
#  '2h 5min']

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list8=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(70,80):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list8.append(div_element.text.strip())
        else:
            movie_runtime_list8.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list8.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list8
# Out:
# ['2h 52min',
#  '2h 21min',
#  '2h 20min',
#  '1h 47min',
#  '2h 7min',
#  '1h 30min',
#  '2h 35min',
#  '2h 23min',
#  '1h 57min',
#  '1h 43min']

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list9=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(80,90):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list9.append(div_element.text.strip())
        else:
            movie_runtime_list9.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list9.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list9
# Out:
# ['1h 37min',
#  '2h 46min',
#  '2h 24min',
#  '2h 19min',
#  '2h 48min',
#  '1h 47min',
#  '2h 8min',
#  '1h 53min',
#  '2h 13min',
#  '1h 48min']

# %%
# Write Your Code here

# Movie Runtime/Duration

movie_runtime_list10=[]# List to store all movie runtime/duration

# For every movie title present in movies_title_list , Finding their Runtime/Duration
for i in range(90,100):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_runtime_list10.append(div_element.text.strip())
        else:
            movie_runtime_list10.append("No Runtime/Duration mentioned")
    else:
      movie_runtime_list10.append("No Runtime/Duration mentioned")

# %%
movie_runtime_list10
# Out:
# ['2h 15min',
#  '2h 24min',
#  '2h 44min',
#  '2h 28min',
#  '1h 53min',
#  '2h 55min',
#  '2h 26min',
#  '2h 19min',
#  '2h 48min',
#  '2h 11min']

# %%
all_movie_runtime_list = []

# Loop through all movie release year lists
for runtime_list in [movie_runtime_list1,movie_runtime_list2,movie_runtime_list3,movie_runtime_list4,movie_runtime_list5,movie_runtime_list6,movie_runtime_list7,movie_runtime_list8,movie_runtime_list9,movie_runtime_list10]:
  all_movie_runtime_list.extend(runtime_list)  # Add each element of the list

print(all_movie_runtime_list)
# Out:
# ['2h 35min', '3h 0min', '3h 21min', '2h 55min', '2h 40min', '2h 27min', '2h 22min', '2h 18min', '2h 39min', '1h 43min', '2h 30min', '2h 39min', '2h 38min', '2h 35min', '2h 37min', '2h 23min', '2h 21min', '2h 39min', '2h 47min', '2h 32min', '2h 4min', '2h 22min', '2h 49min', '2h 15min', '2h 47min', '1h 39min', '1h 57min', '2h 17min', '2h 2min', '1h 54min', '1h 50min', '2h 34min', '1h 46min', '2h 11min', '2h 19min', '1h 45min', '2h 36min', '2h 13min', '1h 45min', '2h 32min', '3h 26min', '1h 45min', '1h 46min', '2h 34min', '1h 54min', '2h 30min', '2h 46min', '1h 23min', '1h 41min', '2h 2min', '2h 5min', '2h 0min', '2h 24min', '2h 14min', '2h 8min', '3h 0min', '2h 35min', '2h 19min', '1h 30min', '2h 36min', '2h 38min', '2h 35min', '2h 28min', '1h 52min', '2h 49min', '2h 44min', '2h 43min', '2h 30min', '2h 18min', '2h 5min', '2h 52min', '2h 21min', '2h 20min', '1h 47min', '2h 7min', '1h 30min', '2h 35min', '2h 23min', '1h 57min', '1h 43min', '1h 37min', '2h 46min', '2h 24min', '2h 19min',
# ...

# %% [markdown]
# # Scrapping Age Rating

# %%
# Write Your Code here
movie_age_rating_list1 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(0,10):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list1.append(div_element.text.strip())
        else:
            movie_age_rating_list1.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list1.append("Age Rating Not Listed.")

# %%
movie_age_rating_list1
# Out:
# ['UA',
#  'UA',
#  'A',
#  'A',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'A',
#  'A',
#  'UA',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
movie_age_rating_list2 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(10,20):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list2.append(div_element.text.strip())
        else:
            movie_age_rating_list2.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list2.append("Age Rating Not Listed.")

# %%
movie_age_rating_list2
# Out:
# ['UA',
#  'UA',
#  'UA',
#  'Age Rating Not Listed.',
#  'UA',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'UA',
#  'UA',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
movie_age_rating_list3 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(20,30):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list3.append(div_element.text.strip())
        else:
            movie_age_rating_list3.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list3.append("Age Rating Not Listed.")

# %%
movie_age_rating_list3
# Out:
# ['Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'UA',
#  'UA',
#  'Age Rating Not Listed.',
#  'A',
#  'Age Rating Not Listed.',
#  'UA',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
movie_age_rating_list4 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(30,40):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list4.append(div_element.text.strip())
        else:
            movie_age_rating_list4.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list4.append("Age Rating Not Listed.")

# %%
movie_age_rating_list4
# Out:
# ['Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'UA',
#  'Age Rating Not Listed.',
#  'UA',
#  'Age Rating Not Listed.',
#  'U',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'U']

# %%
# Write Your Code here
movie_age_rating_list5 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(40,50):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list5.append(div_element.text.strip())
        else:
            movie_age_rating_list5.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list5.append("Age Rating Not Listed.")

# %%
movie_age_rating_list5
# Out:
# ['A',
#  'Age Rating Not Listed.',
#  'UA',
#  'UA',
#  'UA',
#  'UA',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
movie_age_rating_list6 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(50,60):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list6.append(div_element.text.strip())
        else:
            movie_age_rating_list6.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list6.append("Age Rating Not Listed.")

# %%
movie_age_rating_list6
# Out:
# ['Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'U',
#  'A',
#  'Age Rating Not Listed.',
#  'A',
#  'U',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
movie_age_rating_list7 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(60,70):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list7.append(div_element.text.strip())
        else:
            movie_age_rating_list7.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list7.append("Age Rating Not Listed.")

# %%
movie_age_rating_list7
# Out:
# ['A',
#  'Age Rating Not Listed.',
#  'UA',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'UA',
#  'UA',
#  'UA',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
movie_age_rating_list8 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(70,80):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list8.append(div_element.text.strip())
        else:
            movie_age_rating_list8.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list8.append("Age Rating Not Listed.")

# %%
movie_age_rating_list8
# Out:
# ['UA',
#  'UA',
#  'UA',
#  'Age Rating Not Listed.',
#  'UA',
#  'U',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'U',
#  'UA']

# %%
# Write Your Code here
movie_age_rating_list9 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(80,90):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list9.append(div_element.text.strip())
        else:
            movie_age_rating_list9.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list9.append("Age Rating Not Listed.")

# %%
movie_age_rating_list9
# Out:
# ['Age Rating Not Listed.',
#  'UA',
#  'Age Rating Not Listed.',
#  'UA',
#  'UA',
#  'UA',
#  'Age Rating Not Listed.',
#  'A',
#  'Age Rating Not Listed.',
#  'A']

# %%
# Write Your Code here
movie_age_rating_list10 = []# List to store all movie age rating

# For every movie title present in movies_title_list , Finding their Age Rating
for i in range(90,100):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response_g = requests.get(absolute_url)
    soup = BeautifulSoup(response_g.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_age_rating_list10.append(div_element.text.strip())
        else:
            movie_age_rating_list10.append("Age Rating Not Listed.")
    else:
         movie_age_rating_list10.append("Age Rating Not Listed.")

# %%
movie_age_rating_list10
# Out:
# ['U',
#  'A',
#  'A',
#  'UA',
#  'A',
#  'UA',
#  'A',
#  'UA',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
all_movie_age_rating_list = []

# Loop through all movie release year lists
for movie_age_list in [movie_age_rating_list1,movie_age_rating_list2,movie_age_rating_list3,movie_age_rating_list4,movie_age_rating_list5,movie_age_rating_list6,movie_age_rating_list7,movie_age_rating_list8,movie_age_rating_list9,movie_age_rating_list10]:
  all_movie_age_rating_list.extend(movie_age_list)  # Add each element of the list

print(all_movie_age_rating_list)
# Out:
# ['UA', 'UA', 'A', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'A', 'UA', 'Age Rating Not Listed.', 'UA', 'UA', 'UA', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'UA', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.', 'UA', 'Age Rating Not Listed.', 'U', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'U', 'A', 'Age Rating Not Listed.', 'UA', 'UA', 'UA', 'UA', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'U', 'A', 'Age Rating Not Listed.', 'A', 'U', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'UA', 'Age Rating 
# ...

# %% [markdown]
# # Fetching Production Countries Details

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list1=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(0,10):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list1.append(div_element.text.strip())
        else:
            movie_production_country_list1.append("Production Country Not Listed")
    else:
       movie_production_country_list1.append("Production Country Not Listed")

# %%
movie_production_country_list1
# Out:
# ['United States',
#  'United States, United Kingdom',
#  'India',
#  'India',
#  'India',
#  'India',
#  'United Kingdom, United States, Ireland',
#  'India',
#  'India',
#  'United States, Australia']

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list2=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(10,20):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list2.append(div_element.text.strip())
        else:
            movie_production_country_list2.append("Production Country Not Listed")
    else:
       movie_production_country_list2.append("Production Country Not Listed")

# %%
movie_production_country_list2
# Out:
# ['India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'India',
#  'France']

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list3=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(20,30):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list3.append(div_element.text.strip())
        else:
            movie_production_country_list3.append("Production Country Not Listed")
    else:
       movie_production_country_list3.append("Production Country Not Listed")

# %%
movie_production_country_list3
# Out:
# ['United States',
#  'India',
#  'India',
#  'India',
#  'United States',
#  'Canada, United Kingdom, United States',
#  'United States',
#  'India',
#  'India',
#  'Poland']

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list4=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(30,40):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list4.append(div_element.text.strip())
        else:
            movie_production_country_list4.append("Production Country Not Listed")
    else:
       movie_production_country_list4.append("Production Country Not Listed")

# %%
movie_production_country_list4
# Out:
# ['United States',
#  'India',
#  'United Kingdom, United States, Poland',
#  'United States',
#  'India',
#  'United States, United Kingdom',
#  'India',
#  'United States',
#  'United States',
#  'United States, United Kingdom']

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list5=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(40,50):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list5.append(div_element.text.strip())
        else:
            movie_production_country_list5.append("Production Country Not Listed")
    else:
       movie_production_country_list5.append("Production Country Not Listed")

# %%
movie_production_country_list5
# Out:
# ['United States',
#  'United States, United Kingdom',
#  'United States, South Korea',
#  'India',
#  'United Kingdom, United States',
#  'India',
#  'India',
#  'Canada, France, United States',
#  'United States, Canada',
#  'India']

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list6=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(50,60):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list6.append(div_element.text.strip())
        else:
            movie_production_country_list6.append("Production Country Not Listed")
    else:
       movie_production_country_list6.append("Production Country Not Listed")

# %%
movie_production_country_list6
# Out:
# ['Japan',
#  'Canada',
#  'India',
#  'India',
#  'India',
#  'United States',
#  'India',
#  'Australia, China, United Kingdom, United States',
#  'India',
#  'India']

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list7=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(60,70):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list7.append(div_element.text.strip())
        else:
            movie_production_country_list7.append("Production Country Not Listed")
    else:
       movie_production_country_list7.append("Production Country Not Listed")

# %%
movie_production_country_list7
# Out:
# ['United Kingdom, United States',
#  'India',
#  'India',
#  'India',
#  'United Kingdom, United States',
#  'United States',
#  'India',
#  'India',
#  'India',
#  'India']

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list8=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(70,80):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list8.append(div_element.text.strip())
        else:
            movie_production_country_list8.append("Production Country Not Listed")
    else:
       movie_production_country_list8.append("Production Country Not Listed")

# %%
movie_production_country_list8
# Out:
# ['India',
#  'United States',
#  'India',
#  'United States, Czech Republic',
#  'India',
#  'United States',
#  'India',
#  'India',
#  'United Kingdom, United States',
#  'United States, United Kingdom']

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list9=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(80,90):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list9.append(div_element.text.strip())
        else:
            movie_production_country_list9.append("Production Country Not Listed")
    else:
       movie_production_country_list9.append("Production Country Not Listed")

# %%
movie_production_country_list9
# Out:
# ['United States',
#  'India',
#  'United States, Spain',
#  'India',
#  'India',
#  'United Kingdom, United States',
#  'United States',
#  'Sweden, India',
#  'India',
#  'United States']

# %%
# Write Your Code here
# Movie Production Country

movie_production_country_list10=[]# List to store all movie production country

# For every movie title present in movies_title_list , Finding their Production country
for i in range(90,100):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            movie_production_country_list10.append(div_element.text.strip())
        else:
            movie_production_country_list10.append("Production Country Not Listed")
    else:
       movie_production_country_list10.append("Production Country Not Listed")

# %%
movie_production_country_list10
# Out:
# ['India',
#  'United States',
#  'Canada, United Kingdom, United States',
#  'United States',
#  'United States, United Kingdom',
#  'India',
#  'Poland',
#  'India',
#  'India',
#  'United Kingdom, United States']

# %%
all_movie_production_country_list = []

# Loop through all movie release year lists
for movie_prod_list in [movie_production_country_list1,movie_production_country_list2,movie_production_country_list3,movie_production_country_list4,movie_production_country_list5,movie_production_country_list6,movie_production_country_list7,movie_production_country_list8,movie_production_country_list9,movie_production_country_list10]:
  all_movie_production_country_list.extend(movie_prod_list)  # Add each element of the list

print(all_movie_production_country_list)
# Out:
# ['United States', 'United States, United Kingdom', 'India', 'India', 'India', 'India', 'United Kingdom, United States, Ireland', 'India', 'India', 'United States, Australia', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'France', 'United States', 'India', 'India', 'India', 'United States', 'Canada, United Kingdom, United States', 'United States', 'India', 'India', 'Poland', 'United States', 'India', 'United Kingdom, United States, Poland', 'United States', 'India', 'United States, United Kingdom', 'India', 'United States', 'United States', 'United States, United Kingdom', 'United States', 'United States, United Kingdom', 'United States, South Korea', 'India', 'United Kingdom, United States', 'India', 'India', 'Canada, France, United States', 'United States, Canada', 'India', 'Japan', 'Canada', 'India', 'India', 'India', 'United States', 'India', 'Australia, China, United Kingdom, United States', 'India', 'India', 'United Kingdom, United States', 'I
# ...

# %% [markdown]
# # Fetching Streaming Service Details

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list1=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(0,10):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list1.append(alt_text)
                else:
                    movie_streaming_list1.append("Not Available for Streaming.")
            else:
                movie_streaming_list1.append("Not Available for Streaming.")
        else:
            movie_streaming_list1.append("Not Available for Streaming.")
    else:
        movie_streaming_list1.append("Not Available for Streaming.")

# %%
movie_streaming_list1
# Out:
# ['Netflix',
#  'Jio Cinema',
#  'Netflix',
#  'Netflix',
#  'Netflix',
#  'Hotstar',
#  'Not Available for Streaming.',
#  'Zee5',
#  'Not Available for Streaming.',
#  'Not Available for Streaming.']

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list2=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(10,20):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list2.append(alt_text)
                else:
                    movie_streaming_list2.append("Not Available for Streaming.")
            else:
                movie_streaming_list2.append("Not Available for Streaming.")
        else:
            movie_streaming_list2.append("Not Available for Streaming.")
    else:
        movie_streaming_list2.append("Not Available for Streaming.")

# %%
movie_streaming_list2
# Out:
# ['Zee5',
#  'Amazon Prime Video',
#  'Not Available for Streaming.',
#  'Sun Nxt',
#  'Amazon Prime Video',
#  'Netflix',
#  'Not Available for Streaming.',
#  'Netflix',
#  'Not Available for Streaming.',
#  'Not Available for Streaming.']

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list3=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(20,30):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list3.append(alt_text)
                else:
                    movie_streaming_list3.append("Not Available for Streaming.")
            else:
                movie_streaming_list3.append("Not Available for Streaming.")
        else:
            movie_streaming_list3.append("Not Available for Streaming.")
    else:
        movie_streaming_list3.append("Not Available for Streaming.")

# %%
movie_streaming_list3
# Out:
# ['Not Available for Streaming.',
#  'Netflix',
#  'Netflix',
#  'Not Available for Streaming.',
#  'Not Available for Streaming.',
#  'Amazon Prime Video',
#  'Amazon Prime Video',
#  'Amazon Prime Video',
#  'Not Available for Streaming.',
#  'Netflix']

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list4=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(30,40):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list4.append(alt_text)
                else:
                    movie_streaming_list4.append("Not Available for Streaming.")
            else:
                movie_streaming_list4.append("Not Available for Streaming.")
        else:
            movie_streaming_list4.append("Not Available for Streaming.")
    else:
        movie_streaming_list4.append("Not Available for Streaming.")

# %%
movie_streaming_list4
# Out:
# ['Netflix',
#  'Not Available for Streaming.',
#  'Not Available for Streaming.',
#  'Amazon Prime Video',
#  'Sony Liv',
#  'Amazon Prime Video',
#  'Not Available for Streaming.',
#  'Not Available for Streaming.',
#  'Not Available for Streaming.',
#  'Jio Cinema']

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list5=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(40,50):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list5.append(alt_text)
                else:
                    movie_streaming_list5.append("Not Available for Streaming.")
            else:
                movie_streaming_list5.append("Not Available for Streaming.")
        else:
            movie_streaming_list5.append("Not Available for Streaming.")
    else:
        movie_streaming_list5.append("Not Available for Streaming.")

# %%
movie_streaming_list5
# Out:
# ['Apple TV Plus',
#  'Not Available for Streaming.',
#  'Lionsgate Play',
#  'Not Available for Streaming.',
#  'Jio Cinema',
#  'Hotstar',
#  'Amazon Prime Video',
#  'Not Available for Streaming.',
#  'Netflix',
#  'Amazon Prime Video']

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list6=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(50,60):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list6.append(alt_text)
                else:
                    movie_streaming_list6.append("Not Available for Streaming.")
            else:
                movie_streaming_list6.append("Not Available for Streaming.")
        else:
            movie_streaming_list6.append("Not Available for Streaming.")
    else:
        movie_streaming_list6.append("Not Available for Streaming.")

# %%
movie_streaming_list6
# Out:
# ['Not Available for Streaming.',
#  'Amazon Prime Video',
#  'Amazon Prime Video',
#  'Netflix',
#  'Amazon Prime Video',
#  'Lionsgate Play',
#  'Netflix',
#  'Amazon Prime Video',
#  'Amazon Prime Video',
#  'Not Available for Streaming.']

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list7=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(60,70):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list7.append(alt_text)
                else:
                    movie_streaming_list7.append("Not Available for Streaming.")
            else:
                movie_streaming_list7.append("Not Available for Streaming.")
        else:
            movie_streaming_list7.append("Not Available for Streaming.")
    else:
        movie_streaming_list7.append("Not Available for Streaming.")

# %%
movie_streaming_list7
# Out:
# ['Apple TV Plus',
#  'Not Available for Streaming.',
#  'Amazon Prime Video',
#  'Amazon Prime Video',
#  'Netflix',
#  'Amazon Prime Video',
#  'Netflix',
#  'Not Available for Streaming.',
#  'Zee5',
#  'Not Available for Streaming.']

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list8=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(70,80):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list8.append(alt_text)
                else:
                    movie_streaming_list8.append("Not Available for Streaming.")
            else:
                movie_streaming_list8.append("Not Available for Streaming.")
        else:
            movie_streaming_list8.append("Not Available for Streaming.")
    else:
        movie_streaming_list8.append("Not Available for Streaming.")

# %%
movie_streaming_list8
# Out:
# ['Amazon Prime Video',
#  'Jio Cinema',
#  'Not Available for Streaming.',
#  'Netflix',
#  'Not Available for Streaming.',
#  'Not Available for Streaming.',
#  'Amazon Prime Video',
#  'Not Available for Streaming.',
#  'Not Available for Streaming.',
#  'Netflix']

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list9=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(80,90):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list9.append(alt_text)
                else:
                    movie_streaming_list9.append("Not Available for Streaming.")
            else:
                movie_streaming_list9.append("Not Available for Streaming.")
        else:
            movie_streaming_list9.append("Not Available for Streaming.")
    else:
        movie_streaming_list9.append("Not Available for Streaming.")

# %%
movie_streaming_list9
# Out:
# ['Amazon Prime Video',
#  'Jio Cinema',
#  'Netflix',
#  'Amazon Prime Video',
#  'Zee5',
#  'Jio Cinema',
#  'Jio Cinema',
#  'Not Available for Streaming.',
#  'Amazon Prime Video',
#  'Not Available for Streaming.']

# %%
# Write Your Code here
# Movie Streaming Service Platform

movie_streaming_list10=[]# List to store all movie streaming platform

# For every movie title present in movies_title_list , Finding their Streaming Platform
for i in range(90,100):

    # Constructing the absolute URL for fetching each movie
    absolute_url = 'https://www.justwatch.com/in/movie/' + movie_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    movie_streaming_list10.append(alt_text)
                else:
                    movie_streaming_list10.append("Not Available for Streaming.")
            else:
                movie_streaming_list10.append("Not Available for Streaming.")
        else:
            movie_streaming_list10.append("Not Available for Streaming.")
    else:
        movie_streaming_list10.append("Not Available for Streaming.")

# %%
movie_streaming_list10
# Out:
# ['Amazon Prime Video',
#  'Jio Cinema',
#  'Netflix',
#  'Sony Liv',
#  'Lionsgate Play',
#  'Amazon Prime Video',
#  'Amazon Prime Video',
#  'Not Available for Streaming.',
#  'Amazon Prime Video',
#  'Not Available for Streaming.']

# %%
all_movie_streaming_list= []

# Loop through all movie release year lists
for movie_strem_list in [movie_streaming_list1,movie_streaming_list2,movie_streaming_list3,movie_streaming_list4,movie_streaming_list5,movie_streaming_list6,movie_streaming_list7,movie_streaming_list8,movie_streaming_list9,movie_streaming_list10]:
  all_movie_streaming_list.extend(movie_strem_list)  # Add each element of the list

print(all_movie_streaming_list)
# Out:
# ['Netflix', 'Jio Cinema', 'Netflix', 'Netflix', 'Netflix', 'Hotstar', 'Not Available for Streaming.', 'Zee5', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Zee5', 'Amazon Prime Video', 'Not Available for Streaming.', 'Sun Nxt', 'Amazon Prime Video', 'Netflix', 'Not Available for Streaming.', 'Netflix', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Netflix', 'Netflix', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Amazon Prime Video', 'Amazon Prime Video', 'Amazon Prime Video', 'Not Available for Streaming.', 'Netflix', 'Netflix', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Amazon Prime Video', 'Sony Liv', 'Amazon Prime Video', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Not Available for Streaming.', 'Jio Cinema', 'Apple TV Plus', 'Not Available for Streaming.', 'Lionsgate Play', 'Not Available for Streaming.', 'Jio Cinema', 'Hotstar', 'Amazon Prime Video
# ...

# %% [markdown]
# # Now Creating Movies DataFrame

# %%
# Write Your Code here
# Creating Movies Dataframe

data_movies = {
    'Movie Title':movie_title_list,
    'IMDB Rating':all_movie_imdb_list,
    'Release Year':all_release_years,
    'Genre': all_movie_genre_list,
    'Runtime/Duration':all_movie_runtime_list,
    'Age Rating':all_movie_age_rating_list,
    'Production Country':all_movie_production_country_list,
    'Streaming Platform':all_movie_streaming_list,
    'Url':movie_url_list
}

df_movies = pd.DataFrame(data_movies)

# %%
df_movies
# Out:
#                       Movie Title  IMDB Rating Release Year  \
# 0                       DUNE-2021  8.0  (807k)        2021
# 1                     OPPENHEIMER  8.4  (676k)        2023
# 2                     ANIMAL-2022   6.3  (84k)        2023
# 3                          SALAAR   6.5  (61k)        2023
# 4                           DUNKI   6.7  (70k)        2023
# ..                            ...          ...          ...
# 95                         PUSHPA   7.6  (86k)        2021
# 96            DZIEWCZYNY-Z-DUBAJU    5.2  (2k)        2021
# 97                 MAIN-ATAL-HOON    7.3  (3k)        2024
# 98  ROCKY-AUR-RANI-KI-PREM-KAHANI   6.5  (41k)        2023
# 99                       SALTBURN  7.0  (189k)        2023
#
#                                                 Genre Runtime/Duration  \
# 0          Science-Fiction, Action & Adventure, Drama         2h 35min
# 1                                      Drama, History          3h 0min
# ...

# %%
# Specifying the URL from which tv show related data will be fetched
tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'
# Sending an HTTP GET request to the URL
page=requests.get(tv_url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser'
soup=BeautifulSoup(page.text,'html.parser')
# Printing the prettified HTML content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
# ...

# %%
# Write Your Code here

# URL from which tv shows data is fetched
tv_url='https://www.justwatch.com/in/tv-shows?release_year_from=2000'

# Sending an HTTP GET request to the URL
response = requests.get(tv_url)

# Parsing HTML content with Beautiful Soup
soup_tv = BeautifulSoup(response.text,'html.parser')

# %% [markdown]
# # Fetching Tv Show Title details

# %%
# Write Your Code here
# Tv Shows title

tv_show_title_list=[] # List to store all tv show title

# Extracting all tv show titles and storing them in tv_show_titles
tv_show_titles = soup_tv.find_all('a',class_='title-list-grid__item--link',attrs={'href':True})

# Extracting each tv show title from tv_show_titles and storing in tv_show_title_list
for tv_show_title in tv_show_titles:

    # Extract the 'href' attribute value, which contains the tv_show title
    data_id_value = tv_show_title['href']

    # Removing the '/in/tv-show/' prefix to get the clean tv_show title
    data_id_value = data_id_value.replace("/in/tv-show/","")

    # Converting the tv_show title to uppercase and appending to the list
    tv_show_title_list.append(data_id_value.upper())

# %%
tv_show_title_list
# Out:
# ['SHOGUN-2024',
#  'PANCHAYAT',
#  'MIRZAPUR',
#  'GAME-OF-THRONES',
#  'AVATAR-THE-LAST-AIRBENDER',
#  'SUNFLOWER-2021',
#  'SOLO-LEVELING-2024',
#  'TRUE-DETECTIVE',
#  'MAHARANI-2021',
#  'YOUNG-SHELDON',
#  'AARYA',
#  'ONE-DAY',
#  'POACHER',
#  'MAAMLA-LEGAL-HAI',
#  'DEATH-AND-OTHER-DETAILS',
#  'MASTRAM',
#  'FARZI',
#  'JUJUTSU-KAISEN',
#  'HALO',
#  'AVATAR-THE-LAST-AIRBENDER-2005',
#  'CRIMINAL-JUSTICE-2019',
#  'INDIAN-POLICE-FORCE',
#  'YELLOWSTONE',
#  'THE-GENTLEMEN',
#  'JACK-REACHER',
#  'THE-TWELVE',
#  'SUPERSEX',
#  'AASHRAM',
#  'SCAM-1992',
#  'PAPERHOUSE',
#  'LOKI',
#  'EUPHORIA',
#  'THE-ROOKIE',
#  'THE-FAMILY-MAN',
#  'LUCIFER',
#  'GANDII-BAAT',
#  'GULLAK',
#  'BIGG-BOSS',
#  'THE-INDRANI-MUKERJEA-STORY-BURIED-TRUTH',
#  'HOUSE-OF-NINJAS',
#  'BREAKING-BAD',
#  'DEMON-SLAYER-KIMETSU-NO-YAIBA',
#  'MASHLE-MAGIC-AND-MUSCLES',
#  'THE-GREAT-INDIAN-MURDER',
#  'MASTERS-OF-THE-AIR',
#  'NARUTO-SHIPPUDEN',
#  'NARUTO',
#  'HOUSE-OF-THE-DRAGON',
# ...

# %% [markdown]
# # Fetching Tv shows Url details

# %%
# Tv Shows url
tv_show_url_list=[] # List to store all tv show urls

# For every tv show title present in tv_show_title_list , Finding their url
for tv_show in tv_show_title_list:

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show

    tv_show_url_list.append(absolute_url)

# %%
tv_show_url_list
# Out:
# ['https://www.justwatch.com/in/tv-show/SHOGUN-2024',
#  'https://www.justwatch.com/in/tv-show/PANCHAYAT',
#  'https://www.justwatch.com/in/tv-show/MIRZAPUR',
#  'https://www.justwatch.com/in/tv-show/GAME-OF-THRONES',
#  'https://www.justwatch.com/in/tv-show/AVATAR-THE-LAST-AIRBENDER',
#  'https://www.justwatch.com/in/tv-show/SUNFLOWER-2021',
#  'https://www.justwatch.com/in/tv-show/SOLO-LEVELING-2024',
#  'https://www.justwatch.com/in/tv-show/TRUE-DETECTIVE',
#  'https://www.justwatch.com/in/tv-show/MAHARANI-2021',
#  'https://www.justwatch.com/in/tv-show/YOUNG-SHELDON',
#  'https://www.justwatch.com/in/tv-show/AARYA',
#  'https://www.justwatch.com/in/tv-show/ONE-DAY',
#  'https://www.justwatch.com/in/tv-show/POACHER',
#  'https://www.justwatch.com/in/tv-show/MAAMLA-LEGAL-HAI',
#  'https://www.justwatch.com/in/tv-show/DEATH-AND-OTHER-DETAILS',
#  'https://www.justwatch.com/in/tv-show/MASTRAM',
#  'https://www.justwatch.com/in/tv-show/FARZI',
# ...

# %% [markdown]
# # Fetching Release Year

# %%
# List to store all TV show release years
tv_show_release_year_list = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(0,10):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list.append(tv_show_release_year)
        else:
            tv_show_release_year_list.append("Release Year Not Listed")
    else:
        tv_show_release_year_list.append("Release Year Not Listed")

# %%
tv_show_release_year_list
# Out:
# ['2024',
#  '2020',
#  '2018',
#  '2011',
#  '2024',
#  '2021',
#  '2024',
#  '2014',
#  '2021',
#  '2017']

# %%
# List to store all TV show release years
tv_show_release_year_list2 = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(10,20):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list2.append(tv_show_release_year)
        else:
            tv_show_release_year_list2.append("Release Year Not Listed")
    else:
        tv_show_release_year_list2.append("Release Year Not Listed")

# %%
tv_show_release_year_list2
# Out:
# ['2020',
#  '2024',
#  '2023',
#  '2024',
#  '2024',
#  '2020',
#  '2023',
#  '2020',
#  '2022',
#  '2005']

# %%
# List to store all TV show release years
tv_show_release_year_list3 = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(20,30):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list3.append(tv_show_release_year)
        else:
            tv_show_release_year_list3.append("Release Year Not Listed")
    else:
        tv_show_release_year_list3.append("Release Year Not Listed")

# %%
tv_show_release_year_list3
# Out:
# ['2019',
#  '2024',
#  '2018',
#  '2024',
#  '2022',
#  '2019',
#  '2024',
#  '2020',
#  '2020',
#  '2017']

# %%
# List to store all TV show release years
tv_show_release_year_list4 = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(30,40):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list4.append(tv_show_release_year)
        else:
            tv_show_release_year_list4.append("Release Year Not Listed")
    else:
        tv_show_release_year_list4.append("Release Year Not Listed")

# %%
tv_show_release_year_list4
# Out:
# ['2021',
#  '2019',
#  '2018',
#  '2019',
#  '2016',
#  '2018',
#  '2019',
#  '2006',
#  '2024',
#  '2024']

# %%
# List to store all TV show release years
tv_show_release_year_list5 = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(40,50):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list5.append(tv_show_release_year)
        else:
            tv_show_release_year_list5.append("Release Year Not Listed")
    else:
        tv_show_release_year_list5.append("Release Year Not Listed")

# %%
tv_show_release_year_list5
# Out:
# ['2008',
#  '2019',
#  '2023',
#  '2022',
#  '2024',
#  '2007',
#  '2002',
#  '2022',
#  '2023',
#  '2009']

# %%
# List to store all TV show release years
tv_show_release_year_list6 = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(50,60):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list6.append(tv_show_release_year)
        else:
            tv_show_release_year_list6.append("Release Year Not Listed")
    else:
        tv_show_release_year_list6.append("Release Year Not Listed")

# %%
tv_show_release_year_list6
# Out:
# ['2024',
#  '2024',
#  '2022',
#  '2023',
#  '2018',
#  '2021',
#  '2020',
#  '2014',
#  '2013',
#  '2018']

# %%
# List to store all TV show release years
tv_show_release_year_list7 = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(60,70):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list7.append(tv_show_release_year)
        else:
            tv_show_release_year_list7.append("Release Year Not Listed")
    else:
        tv_show_release_year_list7.append("Release Year Not Listed")

# %%
tv_show_release_year_list7
# Out:
# ['2010',
#  '2022',
#  '2021',
#  '2021',
#  '2023',
#  '2009',
#  '2020',
#  '2016',
#  '2023',
#  '2024']

# %%
# List to store all TV show release years
tv_show_release_year_list8 = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(70,80):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list8.append(tv_show_release_year)
        else:
            tv_show_release_year_list8.append("Release Year Not Listed")
    else:
        tv_show_release_year_list8.append("Release Year Not Listed")

# %%
tv_show_release_year_list8
# Out:
# ['2020',
#  '2014',
#  '2020',
#  '2023',
#  '2024',
#  '2019',
#  '2023',
#  '2023',
#  '2017',
#  '2015']

# %%
# List to store all TV show release years
tv_show_release_year_list9 = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(80,90):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list9.append(tv_show_release_year)
        else:
            tv_show_release_year_list9.append("Release Year Not Listed")
    else:
        tv_show_release_year_list9.append("Release Year Not Listed")

# %%
tv_show_release_year_list9
# Out:
# ['2018',
#  '2018',
#  '2024',
#  '2014',
#  '2014',
#  '2018',
#  '2010',
#  '2011',
#  '2021',
#  '2023']

# %%
# List to store all TV show release years
tv_show_release_year_list10 = []

# For every TV show title present in tv_show_title_list, find their release year
for i in range(90,100):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the span element with class "text-muted"
        span_element = soup.find('span', class_='text-muted')

        if span_element:
            # Extract the text content of the span element and strip any leading/trailing whitespace
            tv_show_release_year = span_element.text.strip()

            # Remove parentheses from the extracted text
            tv_show_release_year = tv_show_release_year.replace("(", "").replace(")", "")

            # Append the release year to the list
            tv_show_release_year_list10.append(tv_show_release_year)
        else:
            tv_show_release_year_list10.append("Release Year Not Listed")
    else:
        tv_show_release_year_list10.append("Release Year Not Listed")

# %%
tv_show_release_year_list10
# Out:
# ['2021',
#  '2011',
#  '2023',
#  '2021',
#  '2023',
#  '2024',
#  '2016',
#  '2023',
#  '2022',
#  '2021']

# %%
all_tv_show_release_year_list= []

# Loop through all movie release year lists
for release_year_list in [tv_show_release_year_list,tv_show_release_year_list2,tv_show_release_year_list3,tv_show_release_year_list4,tv_show_release_year_list5,tv_show_release_year_list6,tv_show_release_year_list7,tv_show_release_year_list8,tv_show_release_year_list9,tv_show_release_year_list10]:
  all_tv_show_release_year_list.extend(release_year_list)  # Add each element of the list

print(all_tv_show_release_year_list)
# Out:
# ['2024', '2020', '2018', '2011', '2024', '2021', '2024', '2014', '2021', '2017', '2020', '2024', '2023', '2024', '2024', '2020', '2023', '2020', '2022', '2005', '2019', '2024', '2018', '2024', '2022', '2019', '2024', '2020', '2020', '2017', '2021', '2019', '2018', '2019', '2016', '2018', '2019', '2006', '2024', '2024', '2008', '2019', '2023', '2022', '2024', '2007', '2002', '2022', '2023', '2009', '2024', '2024', '2022', '2023', '2018', '2021', '2020', '2014', '2013', '2018', '2010', '2022', '2021', '2021', '2023', '2009', '2020', '2016', '2023', '2024', '2020', '2014', '2020', '2023', '2024', '2019', '2023', '2023', '2017', '2015', '2018', '2018', '2024', '2014', '2014', '2018', '2010', '2011', '2021', '2023', '2021', '2011', '2023', '2021', '2023', '2024', '2016', '2023', '2022', '2021']

# %%
all_tv_show_release_year_list

# %% [markdown]
# # Fetching TV Show Genre Details

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list1 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(0,10):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list1.append(div_element.text.strip())
        else:
            tv_show_genre_list1.append("Genre Not Listed")
    else:
         tv_show_genre_list1.append("Genre Not Listed")

# %%
tv_show_genre_list1
# Out:
# ['Drama, War & Military, History',
#  'Comedy, Drama',
#  'Crime, Action & Adventure, Drama, Mystery & Thriller',
#  'Science-Fiction, Drama, Action & Adventure, Fantasy',
#  'Science-Fiction, Action & Adventure, Fantasy, Comedy, Drama, Kids & Family',
#  'Crime, Comedy',
#  'Action & Adventure, Fantasy, Animation, Science-Fiction',
#  'Drama, Mystery & Thriller, Crime',
#  'Drama',
#  'Comedy, Kids & Family']

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list2 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(10,20):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list2.append(div_element.text.strip())
        else:
            tv_show_genre_list2.append("Genre Not Listed")
    else:
         tv_show_genre_list2.append("Genre Not Listed")

# %%
tv_show_genre_list2
# Out:
# ['Crime, Drama, Mystery & Thriller, Action & Adventure',
#  'Comedy, Drama, Romance',
#  'Crime, Drama',
#  'Drama',
#  'Mystery & Thriller, Drama, Crime',
#  'Drama, Comedy, Fantasy',
#  'Crime, Drama, Mystery & Thriller',
#  'Fantasy, Mystery & Thriller, Animation, Action & Adventure, Science-Fiction',
#  'Action & Adventure, Science-Fiction, Mystery & Thriller, War & Military',
#  'Action & Adventure, Science-Fiction, Animation, Kids & Family, Fantasy']

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list3 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(20,30):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list3.append(div_element.text.strip())
        else:
            tv_show_genre_list3.append("Genre Not Listed")
    else:
         tv_show_genre_list3.append("Genre Not Listed")

# %%
tv_show_genre_list3
# Out:
# ['Drama, Mystery & Thriller, Crime',
#  'Crime, Action & Adventure',
#  'Drama, Western',
#  'Action & Adventure, Comedy, Crime, Drama',
#  'Drama, Mystery & Thriller, Action & Adventure, Crime',
#  'Drama, Mystery & Thriller',
#  'Drama, History',
#  'Crime, Drama, Mystery & Thriller',
#  'Crime, Drama, Mystery & Thriller',
#  'Drama, Mystery & Thriller, Action & Adventure, Crime, Made in Europe']

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list4 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(30,40):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list4.append(div_element.text.strip())
        else:
            tv_show_genre_list4.append("Genre Not Listed")
    else:
         tv_show_genre_list4.append("Genre Not Listed")

# %%
tv_show_genre_list4
# Out:
# ['Fantasy, Science-Fiction, Action & Adventure, Drama',
#  'Drama',
#  'Drama, Comedy, Action & Adventure, Crime',
#  'Comedy, Drama, Action & Adventure',
#  'Crime, Science-Fiction, Drama, Fantasy',
#  'Crime, Drama, Mystery & Thriller',
#  'Comedy, Drama, Kids & Family',
#  'Reality TV, Kids & Family',
#  'Documentary, Crime',
#  'Action & Adventure, Drama, Mystery & Thriller']

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list5 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(40,50):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list5.append(div_element.text.strip())
        else:
            tv_show_genre_list5.append("Genre Not Listed")
    else:
         tv_show_genre_list5.append("Genre Not Listed")

# %%
tv_show_genre_list5
# Out:
# ['Drama, Crime, Mystery & Thriller',
#  'Fantasy, Mystery & Thriller, Animation, Action & Adventure, Science-Fiction',
#  'Animation, Action & Adventure, Comedy, Fantasy, Science-Fiction',
#  'Crime, Mystery & Thriller',
#  'Drama, War & Military, Action & Adventure, Mystery & Thriller',
#  'Animation, Action & Adventure, Science-Fiction, Drama, Fantasy, Comedy',
#  'Action & Adventure, Science-Fiction, Animation, Comedy, Fantasy',
#  'Science-Fiction, Drama, Action & Adventure, Fantasy, Romance',
#  'Drama, Horror, Science-Fiction, Mystery & Thriller, Action & Adventure',
#  'Comedy, Drama, Romance']

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list6 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(50,60):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list6.append(div_element.text.strip())
        else:
            tv_show_genre_list6.append("Genre Not Listed")
    else:
         tv_show_genre_list6.append("Genre Not Listed")

# %%
tv_show_genre_list6
# Out:
# ['Comedy, Crime, Mystery & Thriller',
#  'Drama, Comedy, Action & Adventure, Mystery & Thriller, Crime',
#  'Drama, Comedy',
#  'Crime, Mystery & Thriller',
#  'Comedy, Drama',
#  'Science-Fiction, Drama, Action & Adventure, Romance',
#  'Mystery & Thriller, Drama',
#  'Crime, Drama, Mystery & Thriller',
#  'Drama, Crime',
#  'Drama, Action & Adventure, Crime, Mystery & Thriller']

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list7 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(60,70):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list7.append(div_element.text.strip())
        else:
            tv_show_genre_list7.append("Genre Not Listed")
    else:
         tv_show_genre_list7.append("Genre Not Listed")

# %%
tv_show_genre_list7
# Out:
# ['Drama, Romance, Action & Adventure',
#  'Drama, Mystery & Thriller, Crime',
#  'Drama, Mystery & Thriller, Crime',
#  'Reality TV',
#  'Drama, History, Mystery & Thriller',
#  'Science-Fiction, Mystery & Thriller, Drama, Fantasy, Horror, Romance',
#  'Crime, Drama, Mystery & Thriller',
#  'Mystery & Thriller, Drama, Science-Fiction, Fantasy, Horror',
#  'Action & Adventure, Mystery & Thriller, Drama',
#  'Drama, Science-Fiction, Mystery & Thriller']

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list8 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(70,80):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list8.append(div_element.text.strip())
        else:
            tv_show_genre_list8.append("Genre Not Listed")
    else:
         tv_show_genre_list8.append("Genre Not Listed")

# %%
tv_show_genre_list8
# Out:
# ['Drama, Crime',
#  'Action & Adventure, Drama, Crime, Mystery & Thriller',
#  'Crime, Drama, Mystery & Thriller',
#  'Action & Adventure, Science-Fiction, Comedy, Drama, Fantasy',
#  'Romance, Drama',
#  'Drama, Romance',
#  'Drama',
#  'Action & Adventure, Drama, Science-Fiction',
#  'Drama',
#  'Action & Adventure, Animation, Comedy, Fantasy, Science-Fiction, Kids & Family']

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list9 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(80,90):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list9.append(div_element.text.strip())
        else:
            tv_show_genre_list9.append("Genre Not Listed")
    else:
         tv_show_genre_list9.append("Genre Not Listed")

# %%
tv_show_genre_list9
# Out:
# ['Comedy, Drama, Romance',
#  'Comedy, Drama, Romance, Made in Europe',
#  'Science-Fiction, Mystery & Thriller, Drama',
#  'Drama, Science-Fiction, Action & Adventure',
#  'Drama',
#  'Mystery & Thriller, Action & Adventure, Drama, Crime',
#  'Science-Fiction, Action & Adventure, Drama, Mystery & Thriller, Horror',
#  'Drama, Comedy',
#  'Animation, Action & Adventure, Fantasy',
#  'Science-Fiction, Romance, Comedy, Drama, Fantasy']

# %%
# Write Your Code here
# Tv Shows Genre

tv_show_genre_list10 = [] # List to store all tv show Genres

# For every tv show title present in tv_show_title_list , Finding their Genre
for i in range(90,100):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is genres
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Genres')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_genre_list10.append(div_element.text.strip())
        else:
            tv_show_genre_list10.append("Genre Not Listed")
    else:
         tv_show_genre_list10.append("Genre Not Listed")

# %%
tv_show_genre_list10
# Out:
# ['Drama',
#  'Action & Adventure, Crime, Science-Fiction, Drama, Mystery & Thriller',
#  'Action & Adventure, Crime, Drama, Mystery & Thriller',
#  'Science-Fiction, Comedy, Drama',
#  'Mystery & Thriller, Animation, Action & Adventure, Drama, History',
#  'Fantasy, Romance, Comedy, Drama, Science-Fiction',
#  'Mystery & Thriller, Crime, Drama, Made in Europe',
#  'Drama',
#  'Science-Fiction, Mystery & Thriller, Drama, Horror',
#  'Drama, Romance']

# %%
alltv_show_genre_list= []

# Loop through all movie release year lists
for genre_list in [tv_show_genre_list1,tv_show_genre_list2,tv_show_genre_list3,tv_show_genre_list4,tv_show_genre_list5,tv_show_genre_list6,tv_show_genre_list7,tv_show_genre_list8,tv_show_genre_list9,tv_show_genre_list10]:
  alltv_show_genre_list.extend(genre_list)  # Add each element of the list

print(alltv_show_genre_list)
# Out:
# ['Drama, War & Military, History', 'Comedy, Drama', 'Crime, Action & Adventure, Drama, Mystery & Thriller', 'Science-Fiction, Drama, Action & Adventure, Fantasy', 'Science-Fiction, Action & Adventure, Fantasy, Comedy, Drama, Kids & Family', 'Crime, Comedy', 'Action & Adventure, Fantasy, Animation, Science-Fiction', 'Drama, Mystery & Thriller, Crime', 'Drama', 'Comedy, Kids & Family', 'Crime, Drama, Mystery & Thriller, Action & Adventure', 'Comedy, Drama, Romance', 'Crime, Drama', 'Drama', 'Mystery & Thriller, Drama, Crime', 'Drama, Comedy, Fantasy', 'Crime, Drama, Mystery & Thriller', 'Fantasy, Mystery & Thriller, Animation, Action & Adventure, Science-Fiction', 'Action & Adventure, Science-Fiction, Mystery & Thriller, War & Military', 'Action & Adventure, Science-Fiction, Animation, Kids & Family, Fantasy', 'Drama, Mystery & Thriller, Crime', 'Crime, Action & Adventure', 'Drama, Western', 'Action & Adventure, Comedy, Crime, Drama', 'Drama, Mystery & Thriller, Action & Adventure, Cri
# ...

# %%
alltv_show_genre_list

# %%
#Fetching IMDB Rating Details

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list1 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(0,10):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list1.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list1.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list1.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list1.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list1.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list1.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list1.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list1
# Out:
# ['9.2  (28k)',
#  '8.9  (84k)',
#  '8.5  (81k)',
#  '9.2  (2m)',
#  '7.3  (53k)',
#  '7.5  (23k)',
#  '8.5  (10k)',
#  '8.9  (649k)',
#  '7.9  (9k)',
#  '7.6  (97k)']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list2 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(10,20):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list2.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list2.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list2.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list2.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list2.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list2.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list2.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list2
# Out:
# ['7.9  (13k)',
#  '8.2  (31k)',
#  '7.7  (1k)',
#  'IMDb Rating Not Listed',
#  '6.8  (7k)',
#  '7.1  (2k)',
#  '8.4  (44k)',
#  '8.6  (108k)',
#  '7.3  (84k)',
#  '9.3  (364k)']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list3 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(20,30):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list3.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list3.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list3.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list3.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list3.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list3.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list3.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list3
# Out:
# ['8.1  (19k)',
#  '5.1  (57k)',
#  '8.7  (214k)',
#  '8.4  (19k)',
#  '8.1  (204k)',
#  '7.4  (6k)',
#  '6.1  (1k)',
#  '7.4  (32k)',
#  '9.3  (150k)',
#  '8.2  (527k)']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list4 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(30,40):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list4.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list4.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list4.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list4.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list4.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list4.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list4.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list4
# Out:
# ['8.2  (407k)',
#  '8.3  (236k)',
#  '8.0  (68k)',
#  '8.7  (97k)',
#  '8.1  (353k)',
#  '3.4  (2k)',
#  '9.1  (21k)',
#  '3.7  (3k)',
#  '6.3  (1k)',
#  '7.2  (4k)']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list5 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(40,50):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list5.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list5.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list5.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list5.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list5.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list5.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list5.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list5
# Out:
# ['9.5  (2m)',
#  '8.7  (80k)',
#  '7.6  (5k)',
#  '6.8  (13k)',
#  '7.8  (21k)',
#  '8.7  (164k)',
#  '8.4  (125k)',
#  '8.4  (366k)',
#  '8.7  (507k)',
#  '8.5  (478k)']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list6 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(50,60):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list6.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list6.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list6.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list6.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list6.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list6.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list6.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list6
# Out:
# ['7.2  (4k)',
#  '7.0  (31k)',
#  '8.6  (203k)',
#  '6.1  (3k)',
#  '8.8  (266k)',
#  '7.8  (39k)',
#  '6.5  (9k)',
#  '8.9  (418k)',
#  '8.8  (640k)',
#  '8.3  (19k)']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list7 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(60,70):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list7.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list7.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list7.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list7.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list7.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list7.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list7.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list7
# Out:
# ['8.5  (255k)',
#  '8.0  (39k)',
#  '8.2  (45k)',
#  '8.7  (4k)',
#  '8.5  (20k)',
#  '7.7  (307k)',
#  '7.5  (6k)',
#  '8.7  (1m)',
#  '8.1  (6k)',
#  '7.0  (4k)']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list8 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(70,80):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list8.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list8.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list8.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list8.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list8.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list8.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list8.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list8
# Out:
# ['6.4  (6k)',
#  '7.0  (58k)',
#  '8.5  (65k)',
#  '8.3  (144k)',
#  '7.8  (5k)',
#  '5.8',
#  'IMDb Rating Not Listed',
#  '7.0  (36k)',
#  '8.0  (111k)',
#  '8.7  (184k)']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list9 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(80,90):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list9.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list9.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list9.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list9.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list9.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list9.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list9.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list9
# Out:
# ['8.3  (28k)',
#  '8.9  (32k)',
#  '5.9  (1k)',
#  '7.5  (367k)',
#  '8.0  (2k)',
#  '7.9  (44k)',
#  '8.1  (1m)',
#  '8.5  (281k)',
#  '9.1  (12k)',
#  '7.7  (7k)']

# %%
# Write Your Code here
import requests
from bs4 import BeautifulSoup

# List to store all TV show IMDb ratings
tv_show_imdb_list10 = []

# For every TV show title present in tv_show_title_list, find their IMDb rating
for i in range(90,100):
    # Construct the absolute URL for fetching each TV show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)

    # Check if the request was successful
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the h3 element with class "detail-infos__subheading" and string "Rating"
        h3_element = soup.find('h3', class_='detail-infos__subheading', string='Rating')

        if h3_element:
            # Check if the next sibling is a div with class "detail-infos__value"
            div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

            if div_element:
                # Find all div elements with class "jw-scoring-listing__rating" inside div_element
                inside_div = div_element.find_all('div', class_='jw-scoring-listing__rating')

                # Check if inside_div is non-empty
                if inside_div:
                    inside_div_last = inside_div[-1]  # Extracting the last div element

                    # Check if inside_div_last is non-empty
                    if inside_div_last:
                        span_all = inside_div_last.find_all('span')

                        # Check if span_all is non-empty
                        if span_all:
                            span_last = span_all[-1]  # Extracting the last span element
                            tv_show_imdb_list10.append(span_last.text.strip())
                        else:
                            tv_show_imdb_list10.append("IMDb Rating Not Listed")
                    else:
                        tv_show_imdb_list10.append("IMDb Rating Not Listed")
                else:
                    tv_show_imdb_list10.append("IMDb Rating Not Listed")
            else:
                tv_show_imdb_list10.append("IMDb Rating Not Listed")
        else:
            tv_show_imdb_list10.append("IMDb Rating Not Listed")
    else:
        tv_show_imdb_list10.append("IMDb Rating Not Listed")

# %%
tv_show_imdb_list10
# Out:
# ['9.2  (310k)',
#  '8.5  (187k)',
#  '7.0  (26k)',
#  '8.1  (52k)',
#  '8.8  (60k)',
#  '7.9  (3k)',
#  '8.0  (102k)',
#  '7.1',
#  '7.8',
#  '8.3  (42k)']

# %%
all_tv_show_imdb_list= []

# Loop through all movie release year lists
for tv_show_list in [tv_show_imdb_list1,tv_show_imdb_list2,tv_show_imdb_list3,tv_show_imdb_list4,tv_show_imdb_list5,tv_show_imdb_list6,tv_show_imdb_list7,tv_show_imdb_list8,tv_show_imdb_list9,tv_show_imdb_list10]:
  all_tv_show_imdb_list.extend(tv_show_list)  # Add each element of the list

print(all_tv_show_imdb_list)
# Out:
# ['9.2  (28k)', '8.9  (84k)', '8.5  (81k)', '9.2  (2m)', '7.3  (53k)', '7.5  (23k)', '8.5  (10k)', '8.9  (649k)', '7.9  (9k)', '7.6  (97k)', '7.9  (13k)', '8.2  (31k)', '7.7  (1k)', 'IMDb Rating Not Listed', '6.8  (7k)', '7.1  (2k)', '8.4  (44k)', '8.6  (108k)', '7.3  (84k)', '9.3  (364k)', '8.1  (19k)', '5.1  (57k)', '8.7  (214k)', '8.4  (19k)', '8.1  (204k)', '7.4  (6k)', '6.1  (1k)', '7.4  (32k)', '9.3  (150k)', '8.2  (527k)', '8.2  (407k)', '8.3  (236k)', '8.0  (68k)', '8.7  (97k)', '8.1  (353k)', '3.4  (2k)', '9.1  (21k)', '3.7  (3k)', '6.3  (1k)', '7.2  (4k)', '9.5  (2m)', '8.7  (80k)', '7.6  (5k)', '6.8  (13k)', '7.8  (21k)', '8.7  (164k)', '8.4  (125k)', '8.4  (366k)', '8.7  (507k)', '8.5  (478k)', '7.2  (4k)', '7.0  (31k)', '8.6  (203k)', '6.1  (3k)', '8.8  (266k)', '7.8  (39k)', '6.5  (9k)', '8.9  (418k)', '8.8  (640k)', '8.3  (19k)', '8.5  (255k)', '8.0  (39k)', '8.2  (45k)', '8.7  (4k)', '8.5  (20k)', '7.7  (307k)', '7.5  (6k)', '8.7  (1m)', '8.1  (6k)', '7.0  (4k)', '6.4 
# ...

# %% [markdown]
# # Fetching Age Rating Details

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list1 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(0,10):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list1.append(div_element.text.strip())
        else:
            tv_show_age_rating_list1.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list1.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list1
# Out:
# ['Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'U',
#  'Age Rating Not Listed.',
#  'A',
#  'Age Rating Not Listed.',
#  'U',
#  'UA',
#  'U']

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list2 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(10,20):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list2.append(div_element.text.strip())
        else:
            tv_show_age_rating_list2.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list2.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list2
# Out:
# ['Age Rating Not Listed.',
#  'A',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'U']

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list3 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(20,30):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list3.append(div_element.text.strip())
        else:
            tv_show_age_rating_list3.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list3.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list3
# Out:
# ['Age Rating Not Listed.',
#  'A',
#  'Age Rating Not Listed.',
#  'A',
#  'A',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list4 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(30,40):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list4.append(div_element.text.strip())
        else:
            tv_show_age_rating_list4.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list4.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list4
# Out:
# ['Age Rating Not Listed.',
#  'A',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'U',
#  'A',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list5 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(40,50):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list5.append(div_element.text.strip())
        else:
            tv_show_age_rating_list5.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list5.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list5
# Out:
# ['Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list6 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(50,60):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list6.append(div_element.text.strip())
        else:
            tv_show_age_rating_list6.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list6.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list6
# Out:
# ['Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list7 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(50,60):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list7.append(div_element.text.strip())
        else:
            tv_show_age_rating_list7.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list7.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list7
# Out:
# ['Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list8 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(70,80):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list8.append(div_element.text.strip())
        else:
            tv_show_age_rating_list8.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list8.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list8
# Out:
# ['Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list9 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(80,90):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list9.append(div_element.text.strip())
        else:
            tv_show_age_rating_list9.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list9.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list9
# Out:
# ['A',
#  'Age Rating Not Listed.',
#  'A',
#  'U',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'U',
#  'U',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
# Write Your Code here
# Tv Shows Age Rating

tv_show_age_rating_list10 = [] # List to store all tv show Age Ratings

# For every tv show title present in tv_show_title_list , Finding their Age Rating
for i in range(90,100):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is Age rating
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Age rating')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_age_rating_list10.append(div_element.text.strip())
        else:
            tv_show_age_rating_list10.append("Age Rating Not Listed.")
    else:
         tv_show_age_rating_list10.append("Age Rating Not Listed.")

# %%
tv_show_age_rating_list10
# Out:
# ['Age Rating Not Listed.',
#  'U',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'A',
#  'Age Rating Not Listed.',
#  'A',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.',
#  'Age Rating Not Listed.']

# %%
all_tv_show_age_rating_list= []

# Loop through all movie release year lists
for tv_show_list in [tv_show_age_rating_list1,tv_show_age_rating_list2,tv_show_age_rating_list3,tv_show_age_rating_list4,tv_show_age_rating_list5,tv_show_age_rating_list6,tv_show_age_rating_list7,tv_show_age_rating_list8,tv_show_age_rating_list9,tv_show_age_rating_list10]:
  all_tv_show_age_rating_list.extend(tv_show_list)  # Add each element of the list

print(all_tv_show_age_rating_list)
# Out:
# ['Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'U', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'U', 'UA', 'U', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'U', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'A', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'U', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'U', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'A', 'U', 'Age Rating Not Listed.', 'A', 'A', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed.', 'Age Rating Not Listed
# ...

# %% [markdown]
# # Fetching Production Country details

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list1=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(0,10):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list1.append(div_element.text.strip())
        else:
            tv_show_production_country_list1.append("Production Country Not Listed")
    else:
          tv_show_production_country_list1.append("Production Country Not Listed")

# %%
tv_show_production_country_list1
# Out:
# ['United States',
#  'India',
#  'India',
#  'United States',
#  'United States',
#  'India',
#  'Japan, South Korea',
#  'United States',
#  'India',
#  'United States']

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list2=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(10,20):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list2.append(div_element.text.strip())
        else:
            tv_show_production_country_list2.append("Production Country Not Listed")
    else:
          tv_show_production_country_list2.append("Production Country Not Listed")

# %%
tv_show_production_country_list2
# Out:
# ['India',
#  'United Kingdom',
#  'India, United States',
#  'India',
#  'United States',
#  'India',
#  'India',
#  'Japan, United States',
#  'United States',
#  'United States']

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list3=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(20,30):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list3.append(div_element.text.strip())
        else:
            tv_show_production_country_list3.append("Production Country Not Listed")
    else:
          tv_show_production_country_list3.append("Production Country Not Listed")

# %%
tv_show_production_country_list3
# Out:
# ['India',
#  'India',
#  'United States',
#  'United Kingdom, United States',
#  'United States',
#  'Belgium',
#  'Italy',
#  'India',
#  'India',
#  'Spain']

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list4=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(30,40):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list4.append(div_element.text.strip())
        else:
            tv_show_production_country_list4.append("Production Country Not Listed")
    else:
          tv_show_production_country_list4.append("Production Country Not Listed")

# %%
tv_show_production_country_list4
# Out:
# ['United States',
#  'United States',
#  'United States',
#  'India',
#  'United States',
#  'India',
#  'India',
#  'India',
#  'India',
#  'Japan']

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list5=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(40,50):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list5.append(div_element.text.strip())
        else:
            tv_show_production_country_list5.append("Production Country Not Listed")
    else:
          tv_show_production_country_list5.append("Production Country Not Listed")

# %%
tv_show_production_country_list5
# Out:
# ['United States',
#  'Japan',
#  'Japan',
#  'India',
#  'United States',
#  'Japan',
#  'Japan',
#  'United States',
#  'United States',
#  'United States']

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list6=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(50,60):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list6.append(div_element.text.strip())
        else:
            tv_show_production_country_list6.append("Production Country Not Listed")
    else:
          tv_show_production_country_list6.append("Production Country Not Listed")

# %%
tv_show_production_country_list6
# Out:
# ['South Korea',
#  'United States',
#  'United States',
#  'India',
#  'United States',
#  'United States',
#  'Mexico',
#  'United States',
#  'United Kingdom',
#  'India']

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list7=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(60,70):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list7.append(div_element.text.strip())
        else:
            tv_show_production_country_list7.append("Production Country Not Listed")
    else:
          tv_show_production_country_list7.append("Production Country Not Listed")

# %%
tv_show_production_country_list7
# Out:
# ['United States',
#  'United States',
#  'United States',
#  'India',
#  'India',
#  'United States',
#  'Brazil',
#  'United States',
#  'India',
#  'Germany, United Kingdom, France']

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list8=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(70,80):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list8.append(div_element.text.strip())
        else:
            tv_show_production_country_list8.append("Production Country Not Listed")
    else:
          tv_show_production_country_list8.append("Production Country Not Listed")

# %%
tv_show_production_country_list8
# Out:
# ['India',
#  'United States',
#  'India',
#  'United States',
#  'India',
#  'India',
#  'India',
#  'United States',
#  'United States',
#  'Japan']

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list9=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(80,90):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list9.append(div_element.text.strip())
        else:
            tv_show_production_country_list9.append("Production Country Not Listed")
    else:
          tv_show_production_country_list9.append("Production Country Not Listed")

# %%
tv_show_production_country_list9
# Out:
# ['India',
#  'India',
#  'Germany',
#  'United States',
#  'India',
#  'United States',
#  'United States',
#  'United States',
#  'India',
#  'South Korea']

# %%
# Write Your Code here
# Tv Shows Production Country

tv_show_production_country_list10=[] # List to store all tv show Production Countries

# For every tv show title present in tv_show_title_list , Finding their Production country
for i in range(90,100):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose sub-heading inside details- infos is 'Production Country'
    h3_element = soup.find('h3', class_='detail-infos__subheading', string=' Production country ')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_production_country_list10.append(div_element.text.strip())
        else:
            tv_show_production_country_list10.append("Production Country Not Listed")
    else:
          tv_show_production_country_list10.append("Production Country Not Listed")

# %%
tv_show_production_country_list10
# Out:
# ['India',
#  'United States',
#  'Spain',
#  'United States',
#  'United States',
#  'South Korea',
#  'United Kingdom',
#  'India',
#  'United States',
#  'Sweden']

# %%
alltv_show_production_country_list= []

# Loop through all movie release year lists
for tv_show_production in [tv_show_production_country_list1,tv_show_production_country_list2,tv_show_production_country_list3,tv_show_production_country_list4,tv_show_production_country_list5,tv_show_production_country_list6,tv_show_production_country_list7,tv_show_production_country_list8,tv_show_production_country_list9,tv_show_production_country_list10]:
  alltv_show_production_country_list.extend(tv_show_production)  # Add each element of the list

print(alltv_show_production_country_list)
# Out:
# ['United States', 'India', 'India', 'United States', 'United States', 'India', 'Japan, South Korea', 'United States', 'India', 'United States', 'India', 'United Kingdom', 'India, United States', 'India', 'United States', 'India', 'India', 'Japan, United States', 'United States', 'United States', 'India', 'India', 'United States', 'United Kingdom, United States', 'United States', 'Belgium', 'Italy', 'India', 'India', 'Spain', 'United States', 'United States', 'United States', 'India', 'United States', 'India', 'India', 'India', 'India', 'Japan', 'United States', 'Japan', 'Japan', 'India', 'United States', 'Japan', 'Japan', 'United States', 'United States', 'United States', 'South Korea', 'United States', 'United States', 'India', 'United States', 'United States', 'Mexico', 'United States', 'United Kingdom', 'India', 'United States', 'United States', 'United States', 'India', 'India', 'United States', 'Brazil', 'United States', 'India', 'Germany, United Kingdom, France', 'India', 'Unit
# ...

# %%
alltv_show_production_country_list

# %% [markdown]
# # Fetching Streaming Service details

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list1=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(0,10):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list1.append(alt_text)
                else:
                    tv_show_streaming_list1.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list1.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list1.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list1.append("Not Available for Streaming.")

# %%
tv_show_streaming_list1
# Out:
# ['Hotstar',
#  'Amazon Prime Video',
#  'Amazon Prime Video',
#  'Jio Cinema',
#  'Netflix',
#  'VI movies and tv',
#  'Crunchyroll',
#  'Jio Cinema',
#  'Sony Liv',
#  'Amazon Prime Video']

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list2=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(10,20):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list2.append(alt_text)
                else:
                    tv_show_streaming_list2.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list2.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list2.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list2.append("Not Available for Streaming.")

# %%
tv_show_streaming_list2
# Out:
# ['Hotstar',
#  'Netflix',
#  'Amazon Prime Video',
#  'Netflix',
#  'Hotstar',
#  'Not Available for Streaming.',
#  'Amazon Prime Video',
#  'Netflix',
#  'Jio Cinema',
#  'Not Available for Streaming.']

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list3=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(20,30):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list3.append(alt_text)
                else:
                    tv_show_streaming_list3.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list3.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list3.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list3.append("Not Available for Streaming.")

# %%
tv_show_streaming_list3
# Out:
# ['Hotstar',
#  'Amazon Prime Video',
#  'Netflix',
#  'Netflix',
#  'Amazon Prime Video',
#  'Netflix',
#  'Netflix',
#  'MX Player',
#  'Sony Liv',
#  'Netflix']

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list4=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(30,40):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list4.append(alt_text)
                else:
                    tv_show_streaming_list4.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list4.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list4.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list4.append("Not Available for Streaming.")

# %%
tv_show_streaming_list4
# Out:
# ['Hotstar',
#  'Jio Cinema',
#  'Not Available for Streaming.',
#  'Amazon Prime Video',
#  'Netflix',
#  'Alt Balaji',
#  'Sony Liv',
#  'Not Available for Streaming.',
#  'Netflix',
#  'Netflix']

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list5=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(40,50):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list5.append(alt_text)
                else:
                    tv_show_streaming_list5.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list5.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list5.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list5.append("Not Available for Streaming.")

# %%
tv_show_streaming_list5
# Out:
# ['Netflix',
#  'Netflix',
#  'Crunchyroll',
#  'Hotstar',
#  'Apple TV Plus',
#  'Netflix',
#  'Netflix',
#  'Jio Cinema',
#  'Jio Cinema',
#  'Hotstar']

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list6=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(50,60):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list6.append(alt_text)
                else:
                    tv_show_streaming_list6.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list6.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list6.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list6.append("Not Available for Streaming.")

# %%
tv_show_streaming_list6
# Out:
# ['Netflix',
#  'Amazon Prime Video',
#  'Hotstar',
#  'Amazon Prime Video',
#  'Jio Cinema',
#  'Amazon Prime Video',
#  'Netflix',
#  'Not Available for Streaming.',
#  'Netflix',
#  'Jio Cinema']

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list7=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(60,70):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list7.append(alt_text)
                else:
                    tv_show_streaming_list7.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list7.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list7.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list7.append("Not Available for Streaming.")

# %%
tv_show_streaming_list7
# Out:
# ['Lionsgate Play',
#  'Lionsgate Play',
#  'Amazon Prime Video',
#  'Sony Liv',
#  'Netflix',
#  'Netflix',
#  'Netflix',
#  'Netflix',
#  'Hotstar',
#  'Apple TV Plus']

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list8=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(70,80):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list8.append(alt_text)
                else:
                    tv_show_streaming_list8.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list8.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list8.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list8.append("Not Available for Streaming.")

# %%
tv_show_streaming_list8
# Out:
# ['Netflix',
#  'Not Available for Streaming.',
#  'Jio Cinema',
#  'Netflix',
#  'Jio Cinema',
#  'Jio Cinema',
#  'Sony Liv',
#  'Apple TV Plus',
#  'Netflix',
#  'Netflix']

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list9=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(80,90):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list9.append(alt_text)
                else:
                    tv_show_streaming_list9.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list9.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list9.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list9.append("Not Available for Streaming.")

# %%
tv_show_streaming_list9
# Out:
# ['Sony Liv',
#  'Amazon Prime Video',
#  'Netflix',
#  'Not Available for Streaming.',
#  'Jio Cinema',
#  'Hotstar',
#  'Netflix',
#  'Netflix',
#  'Hotstar',
#  'Netflix']

# %%
# Write Your Code here
# Tv Shows Streaming Platform

tv_show_streaming_list10=[] # List to store all tv show Streaming Platorms

# For every tv show title present in tv_show_title_list , Finding their Streaming Platform
for i in range(90,100):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Finding the outer div element with the class "buybox-row stream"
    outer_div = soup.find('div', class_='buybox-row stream')

    if outer_div:
        # Finding the nested div with class "buybox-row__offers" inside the outer div
        inner_div = outer_div.find('div', class_='buybox-row__offers')

        if inner_div:
            # Find the picture element within the nested div
            picture_element = inner_div.find('picture')

            if picture_element:
                # Extract the alt attribute from the img element inside the picture which contains streaming platform name
                img_element = picture_element.find('img')
                if img_element:
                    alt_text = img_element['alt']
                    tv_show_streaming_list10.append(alt_text)
                else:
                    tv_show_streaming_list10.append("Not Available for Streaming.")
            else:
                tv_show_streaming_list10.append("Not Available for Streaming.")
        else:
            tv_show_streaming_list10.append("Not Available for Streaming.")
    else:
        tv_show_streaming_list10.append("Not Available for Streaming.")

# %%
tv_show_streaming_list10
# Out:
# ['Amazon Prime Video',
#  'Not Available for Streaming.',
#  'Netflix',
#  'Jio Cinema',
#  'Netflix',
#  'Amazon Prime Video',
#  'Hotstar',
#  'Amazon miniTV',
#  'Not Available for Streaming.',
#  'Netflix']

# %%
all_tv_show_streaming_list= []

# Loop through all movie release year lists
for tv_show_streaming in [tv_show_streaming_list1,tv_show_streaming_list2,tv_show_streaming_list3,tv_show_streaming_list4,tv_show_streaming_list5,tv_show_streaming_list6,tv_show_streaming_list7,tv_show_streaming_list8,tv_show_streaming_list9,tv_show_streaming_list10]:
  all_tv_show_streaming_list.extend(tv_show_streaming)  # Add each element of the list

print(all_tv_show_streaming_list)
# Out:
# ['Hotstar', 'Amazon Prime Video', 'Amazon Prime Video', 'Jio Cinema', 'Netflix', 'VI movies and tv', 'Crunchyroll', 'Jio Cinema', 'Sony Liv', 'Amazon Prime Video', 'Hotstar', 'Netflix', 'Amazon Prime Video', 'Netflix', 'Hotstar', 'Not Available for Streaming.', 'Amazon Prime Video', 'Netflix', 'Jio Cinema', 'Not Available for Streaming.', 'Hotstar', 'Amazon Prime Video', 'Netflix', 'Netflix', 'Amazon Prime Video', 'Netflix', 'Netflix', 'MX Player', 'Sony Liv', 'Netflix', 'Hotstar', 'Jio Cinema', 'Not Available for Streaming.', 'Amazon Prime Video', 'Netflix', 'Alt Balaji', 'Sony Liv', 'Not Available for Streaming.', 'Netflix', 'Netflix', 'Netflix', 'Netflix', 'Crunchyroll', 'Hotstar', 'Apple TV Plus', 'Netflix', 'Netflix', 'Jio Cinema', 'Jio Cinema', 'Hotstar', 'Netflix', 'Amazon Prime Video', 'Hotstar', 'Amazon Prime Video', 'Jio Cinema', 'Amazon Prime Video', 'Netflix', 'Not Available for Streaming.', 'Netflix', 'Jio Cinema', 'Lionsgate Play', 'Lionsgate Play', 'Amazon Prime Video'
# ...

# %% [markdown]
# # Fetching Duration Details

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list1=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(0,10):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list1.append(div_element.text.strip())
        else:
            tv_show_runtime_list1.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list1.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list1
# Out:
# ['57min',
#  '33min',
#  '50min',
#  '59min',
#  '54min',
#  '37min',
#  '24min',
#  '1h 1min',
#  '44min',
#  '19min']

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list2=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(10,20):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list2.append(div_element.text.strip())
        else:
            tv_show_runtime_list2.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list2.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list2
# Out:
# ['46min',
#  '29min',
#  '47min',
#  '38min',
#  '45min',
#  '28min',
#  '56min',
#  '23min',
#  '52min',
#  '24min']

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list3=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(20,30):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list3.append(div_element.text.strip())
        else:
            tv_show_runtime_list3.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list3.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list3
# Out:
# ['50min',
#  '38min',
#  '50min',
#  '50min',
#  '48min',
#  '54min',
#  '50min',
#  '43min',
#  '52min',
#  '50min']

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list4=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(30,40):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list4.append(div_element.text.strip())
        else:
            tv_show_runtime_list4.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list4.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list4
# Out:
# ['49min',
#  '58min',
#  '43min',
#  '45min',
#  '47min',
#  '44min',
#  '29min',
#  '1h 15min',
#  '46min',
#  '53min']

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list5=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(40,50):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list5.append(div_element.text.strip())
        else:
            tv_show_runtime_list5.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list5.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list5
# Out:
# ['47min',
#  '26min',
#  '23min',
#  '45min',
#  '54min',
#  '24min',
#  '23min',
#  '1h 2min',
#  '58min',
#  '21min']

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list6=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(50,60):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list6.append(div_element.text.strip())
        else:
            tv_show_runtime_list6.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list6.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list6
# Out:
# ['53min',
#  '49min',
#  '34min',
#  '39min',
#  '1h 4min',
#  '42min',
#  '34min',
#  '52min',
#  '58min',
#  '24min']

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list7=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(60,70):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list7.append(div_element.text.strip())
        else:
            tv_show_runtime_list7.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list7.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list7
# Out:
# ['54min',
#  '58min',
#  '47min',
#  '56min',
#  '59min',
#  '42min',
#  '49min',
#  '1h 1min',
#  '50min',
#  '53min']

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list8=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(70,80):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list8.append(div_element.text.strip())
        else:
            tv_show_runtime_list8.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list8.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list8
# Out:
# ['41min',
#  '42min',
#  '47min',
#  '56min',
#  '25min',
#  '29min',
#  '44min',
#  '46min',
#  '43min',
#  '24min']

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list9=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(80,90):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list9.append(div_element.text.strip())
        else:
            tv_show_runtime_list9.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list9.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list9
# Out:
# ['31min',
#  '31min',
#  '1h 2min',
#  '42min',
#  '21min',
#  '43min',
#  '46min',
#  '55min',
#  '21min',
#  '1h 6min']

# %%
# Write Your Code here
# Tv Shows Runtime/Duration

tv_show_runtime_list10=[] # List to store all tv show Runtimes

# For every tv show title present in tv_show_title_list , Finding their Runtime/Duration
for i in range(90,100):

    # Constructing the absolute URL for fetching each tv show
    absolute_url = 'https://www.justwatch.com/in/tv-show/' + tv_show_title_list[i]
    response = requests.get(absolute_url)
    soup = BeautifulSoup(response.text,'html.parser')

    # Selecting only those h3 whose heading is runtine
    h3_element = soup.find('h3', class_='detail-infos__subheading', string='Runtime')

    if h3_element:
        # Check if the next sibling is a div with class "detail-infos__value"
        div_element = h3_element.find_next_sibling('div', class_='detail-infos__value')

        if div_element:
            tv_show_runtime_list10.append(div_element.text.strip())
        else:
            tv_show_runtime_list10.append("No Runtime/Duration mentioned")
    else:
      tv_show_runtime_list10.append("No Runtime/Duration mentioned")

# %%
tv_show_runtime_list10
# Out:
# ['44min',
#  '44min',
#  '48min',
#  '44min',
#  '47min',
#  '1h 3min',
#  '1h 0min',
#  '24min',
#  '50min',
#  '46min']

# %%
all_tv_show_runtime_list= []

# Loop through all movie release year lists
for tv_show_runtime in [tv_show_runtime_list1,tv_show_runtime_list2,tv_show_runtime_list3,tv_show_runtime_list4,tv_show_runtime_list5,tv_show_runtime_list6,tv_show_runtime_list7,tv_show_runtime_list8,tv_show_runtime_list9,tv_show_runtime_list10]:
  all_tv_show_runtime_list.extend(tv_show_runtime)  # Add each element of the list

print(all_tv_show_runtime_list)
# Out:
# ['57min', '33min', '50min', '59min', '54min', '37min', '24min', '1h 1min', '44min', '19min', '46min', '29min', '47min', '38min', '45min', '28min', '56min', '23min', '52min', '24min', '50min', '38min', '50min', '50min', '48min', '54min', '50min', '43min', '52min', '50min', '49min', '58min', '43min', '45min', '47min', '44min', '29min', '1h 15min', '46min', '53min', '47min', '26min', '23min', '45min', '54min', '24min', '23min', '1h 2min', '58min', '21min', '53min', '49min', '34min', '39min', '1h 4min', '42min', '34min', '52min', '58min', '24min', '54min', '58min', '47min', '56min', '59min', '42min', '49min', '1h 1min', '50min', '53min', '41min', '42min', '47min', '56min', '25min', '29min', '44min', '46min', '43min', '24min', '31min', '31min', '1h 2min', '42min', '21min', '43min', '46min', '55min', '21min', '1h 6min', '44min', '44min', '48min', '44min', '47min', '1h 3min', '1h 0min', '24min', '50min', '46min']

# %%
##Creating TV Show DataFrame

# %%
# Write Your Code here
# Creating Tv Shows Dataframe

data_tv_shows = {
    'Tv_Show Title':tv_show_title_list,
    'IMDB Rating':all_tv_show_imdb_list,
    'Release Year':all_tv_show_release_year_list,
    'Genre':alltv_show_genre_list,
    'Runtime/Duration':all_tv_show_runtime_list,
    'Age Rating':all_tv_show_age_rating_list,
    'Production Country':alltv_show_production_country_list,
    'Streaming Platform':all_tv_show_streaming_list,
    'Url':tv_show_url_list
}

df_tv_shows = pd.DataFrame(data_tv_shows)

# %%
df_tv_shows
# Out:
#                 Tv_Show Title  IMDB Rating Release Year  \
# 0                 SHOGUN-2024   9.2  (28k)         2024
# 1                   PANCHAYAT   8.9  (84k)         2020
# 2                    MIRZAPUR   8.5  (81k)         2018
# 3             GAME-OF-THRONES    9.2  (2m)         2011
# 4   AVATAR-THE-LAST-AIRBENDER   7.3  (53k)         2024
# ..                        ...          ...          ...
# 95           MARRY-MY-HUSBAND    7.9  (3k)         2024
# 96          THE-NIGHT-MANAGER  8.0  (102k)         2016
# 97               DEHATI-LADKE          7.1         2023
# 98                       FROM          7.8         2022
# 99               YOUNG-ROYALS   8.3  (42k)         2021
#
#                                                 Genre Runtime/Duration  \
# 0                      Drama, War & Military, History            57min
# 1                                       Comedy, Drama            33min
# 2   Crime, Action & Adventure, Drama, Mystery & Th...            50min
# ...

# %% [markdown]
# # Task 2 :- Data Filtering & Analysis

# %%
# Write Your Code here
# Filtering movies and TV shows to include only those released in the last two years and with an IMDB Rating of 7 or higher.

from datetime import datetime, timedelta

# Get the current date
current_date = datetime.now()

# Calculate the date 2 years ago from the current date
two_years_ago = current_date - timedelta(days=365 * 2)

def filter_df(df, release_year_col, imdb_rating_col, years_ago, current_date):
    # Convert 'Release Year' to datetime format
    #df[release_year_col] = pd.to_datetime(df[release_year_col], errors='coerce')
    df[release_year_col] = pd.to_datetime(df[release_year_col], format='%Y')  # Assuming year only format (YYYY)

    # Filter the DataFrame to include only entries released in the last `years_ago` years
    filtered_df = df[(df[release_year_col] >= two_years_ago) & (df[release_year_col] <= current_date)].copy()

    # Converting 'IMDB Rating' column to a string so that, in the next step, we can convert it to numeric values
    filtered_df.loc[:, imdb_rating_col] = filtered_df[imdb_rating_col].astype(str)

    # Extract numeric part and convert to numeric
    filtered_df[imdb_rating_col] = pd.to_numeric(filtered_df[imdb_rating_col].str.extract(r'([\d.]+)', expand=False), errors='coerce')

    # Filter the DataFrame to include only entries whose IMDb Rating >= 7
    filtered_df = filtered_df[filtered_df[imdb_rating_col] >= 7]
    return filtered_df

# Filtering Movies
filtered_df_movies = filter_df(df_movies, 'Release Year', 'IMDB Rating', two_years_ago, current_date)

# Filtering TV Shows
filtered_df_tv_shows = filter_df(df_tv_shows, 'Release Year', 'IMDB Rating', two_years_ago, current_date)

# %%
print(filtered_df_tv_shows)
# Out:
#                                       Tv_Show Title  IMDB Rating Release Year  \
# 0                                       SHOGUN-2024          9.2   2024-01-01
# 4                         AVATAR-THE-LAST-AIRBENDER          7.3   2024-01-01
# 6                                SOLO-LEVELING-2024          8.5   2024-01-01
# 11                                          ONE-DAY          8.2   2024-01-01
# 12                                          POACHER          7.7   2023-01-01
# 16                                            FARZI          8.4   2023-01-01
# 23                                    THE-GENTLEMEN          8.4   2024-01-01
# 39                                  HOUSE-OF-NINJAS          7.2   2024-01-01
# 42                         MASHLE-MAGIC-AND-MUSCLES          7.6   2023-01-01
# 44                               MASTERS-OF-THE-AIR          7.8   2024-01-01
# 48                                   THE-LAST-OF-US          8.7   2023-01-01
# ...

# %% [markdown]
# # Calculating Mean IMDB Ratings for both Movies and Tv Shows

# %%
# Write Your Code here
# Calculating Movies mean IMDb rating
movie_mean_imdb = filtered_df_movies['IMDB Rating'].mean()
movie_mean_imdb_rounded = round(movie_mean_imdb, 2)
print("Mean IMDb Rating for Movies is:", movie_mean_imdb_rounded)

# Calculating Tv Shows mean IMDb rating
tv_mean_imdb = filtered_df_tv_shows['IMDB Rating'].mean()
tv_mean_imdb_rounded = round(tv_mean_imdb, 2)
print("Mean IMDb Rating for Tv Shows is:", tv_mean_imdb_rounded)
# Out:
# Mean IMDb Rating for Movies is: 7.78
# Mean IMDb Rating for Tv Shows is: 7.85

# %%
# Function for Finding top 5 Highest Imdb rating movies / tv shows

def get_top_5_imdb(df):

  df = df_tv_shows
  # Convert 'IMDB Rating' column to string
  df['IMDB Rating'] = df['IMDB Rating'].astype(str)

  # Extract only the IMDb rating value
  df['IMDB Rating'] = df['IMDB Rating'].str.extract('(\d+\.\d+)')

  # Convert the 'IMDB Rating' column to numeric
  df['IMDB Rating'] = pd.to_numeric(df['IMDB Rating'], errors='coerce')

  # Select the top 5 movies/Tv Shows based on IMDb rating
  top_5 = df.nlargest(5, 'IMDB Rating')


  return top_5

# %%
# Top 5 Highest IMDB Rating Tv Shows

top_5_tv_shows = get_top_5_imdb(filtered_df_tv_shows)
print(top_5_tv_shows.loc[:, ['Tv_Show Title', 'IMDB Rating']])

# %%
#saving final dataframe as Final Data in csv format
# Saving Final Movies/Tv Shows dataframe as Final Data in csv format

df_movies.to_csv('Final_Movies_Data.csv', index=False)
df_tv_shows.to_csv('Final_Tv_Shows_Data.csv', index=False)

# %%
#saving filter data as Filter Data in csv format

# Saving Filtered Movies/Tv Shows dataframe as Filtered Data in csv format

filtered_df_movies.to_csv('Filtered_Movies_Data.csv', index=False)
filtered_df_tv_shows.to_csv('Filtered_Tv_Shows_Data.csv', index=False)
